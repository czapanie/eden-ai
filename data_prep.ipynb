# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mpl

# %%
df = pd.read_csv('dataset.csv')

# %%
df
# Out:
#                      igalki␞Araucaria araucana Unnamed: 1
# 0              igalki␞Abies alba 'Pyramidalis'        NaN
# 1       igalki␞Abies amabilis 'Spreading Star'        NaN
# 2                 igalki␞Abies balsamea 'Nana'        NaN
# 3     igalki␞Abies cephalonica 'Meyer's Dwarf'        NaN
# 4                        igalki␞Abies concolor        NaN
# ...                                        ...        ...
# 2980   pnącza␞Wisteria floribunda 'Shiro-noda'        NaN
# 2981       pnącza␞Wisteria sinensis 'Caroline'        NaN
# 2982       pnącza␞Wisteria sinensis 'Prolific'        NaN
# 2983                  pnącza␞Wisteria sinensis        NaN
# 2984                       pnącza␞Vitis ripida        NaN
#
# [2985 rows x 2 columns]

# %% [markdown]
# ### Przygotowanie Danych

# %%
column_headers = list(df.columns.values)

# %%
df.columns = ['A','B']

# %%
df2 = {'A' : column_headers[0], 'B' : np.nan}
df = df._append(df2, ignore_index = True)

# %%
df
# Out:
#                                              A    B
# 0              igalki␞Abies alba 'Pyramidalis'  NaN
# 1       igalki␞Abies amabilis 'Spreading Star'  NaN
# 2                 igalki␞Abies balsamea 'Nana'  NaN
# 3     igalki␞Abies cephalonica 'Meyer's Dwarf'  NaN
# 4                        igalki␞Abies concolor  NaN
# ...                                        ...  ...
# 2981       pnącza␞Wisteria sinensis 'Caroline'  NaN
# 2982       pnącza␞Wisteria sinensis 'Prolific'  NaN
# 2983                  pnącza␞Wisteria sinensis  NaN
# 2984                       pnącza␞Vitis ripida  NaN
# 2985                 igalki␞Araucaria araucana  NaN
#
# [2986 rows x 2 columns]

# %%
df[df['A'].str.contains("in sorten")]
# Out:
#                                                  A    B
# 523           liściaste␞Buddleja davidii in sorten  NaN
# 636                liściaste␞Cotoneaster in sorten  NaN
# 644                    liściaste␞Cytisus in sorten  NaN
# 672          liściaste␞Euonymus fortunei in sorten  NaN
# 675         liściaste␞Euonymus japonicus in sorten  NaN
# ...                                            ...  ...
# 2971                     pnącza␞Lonicera in sorten  NaN
# 2976         pnącza␞Schisandra chinensis in sorten  NaN
# 2977  pnącza␞Schizophragma hydrangeoides in sorten  NaN
# 2978          pnącza␞Wisteria floribunda in sorten  NaN
# 2979                     pnącza␞Wisteria in sorten  NaN
#
# [65 rows x 2 columns]

# %%
df.drop(df[df['A'].str.contains("in sorten")].index, axis=0, inplace=True)

# %%
df['A'] = df['A'].replace({'®' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'™' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'©' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'PP[0-9]+' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'P[0-9]+' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'PP[A-Z]+' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'EU[0-9]+' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'E[0-9]+' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'PVR' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'PRV' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'PBR' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'WU[0-9]+' : ''}, regex=True)

# %%
df['A'] = df['A'].replace({'SAXZ[0-9]+' : ''}, regex=True)

# %%
df['A'].str.findall('\+E15').tolist()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\+'
# <>:1: SyntaxWarning: invalid escape sequence '\+'
# C:\Users\emilk\AppData\Local\Temp\ipykernel_23468\1062079217.py:1: SyntaxWarning: invalid escape sequence '\+'
#   df['A'].str.findall('\+E15').tolist()
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
df['A'] = df['A'].replace({'\\+E15' : ''}, regex=True)

# %%
df['A'].str.findall('[0-9]+$').tolist()
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
df['A'] = df['A'].replace({'[0-9]+$' : ''}, regex=True)

# %%
df['A'].str.findall("(\'[A-Z][a-z]+\\s[A-Z][a-z]+\'$)").tolist()
# Out:
# [[],
#  ["'Spreading Star'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Dark Hill'"],
#  ["'Green Carpet'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Silver Show'"],
#  [],
#  [],
#  [],
#  ["'Barabits Compact'"],
#  ["'Golden Spreader'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Glauca Prostrata'"],
#  ["'Weismoor Nixie'"],
#  [],
#  [],
#  [],
#  ["'Aurea Robusta'"],
#  [],
#  ["'Glauca Pendula'"],
#  ["'Saphire Nymph'"],
#  ["'Glauca Pyramidalis'"],
#  ["'Horstmanns Silber'"],
#  ["'Feelin Blue'"],
#  ["'Karl Fuchs'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Ellwoodii Gold'"],
#  ["'Imbirica Pendula'"],
#  ["'Snow White'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Gloria Polonica'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Nana Aurea'"],
#  [],
#  ["'Nana Gracilis'"],
#  [],
#  ["'Tsatsumi Gold'"],
#  [],
#  ["'Filifera Nana'"],
#  [],
#  [],
#  [],
#  ["'Teddy Bear'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Blue Alps'"],
#  ["'Kurowao Gold'"],
#  ["'Expansa Aureospicata'"],
#  ["'Expansa Aureovariegata'"],
#  [],
#  ["'Plumosa Aureovariegata'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Constance Franklin'"],
#  ["'Depressa Aurea'"],
#  ["'Gold Cone'"],
#  [],
#  ["'Green Carpet'"],
#  [],
#  [],
#  [],
#  ["'Oblonga Pendula'"],
#  [],
#  ["'Spotty Spreader'"],
#  [],
#  [],
#  [],
#  ["'Emerald Sea'"],
#  ["'Golden Wings'"],
#  [],
#  [],
#  ["'Andorra Compact'"],
#  [],
#  ["'Andorra Variegata'"],
#  ["'Blue Chip'"],
#  ["'Blue Forest'"],
#  [],
#  ["'Golden Carpet'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Golden Saucer'"],
#  [],
#  ["'Gold Star'"],
#  [],
#  ["'Mint Julep'"],
#  ["'Mordigan Gold'"],
#  ["'Old Gold'"],
#  ["'Pfitzeriana Aurea'"],
#  ["'Pfitzeriana Compacta'"],
#  ["'Pfitzeriana Glauca'"],
#  [],
#  ["'Hulsdonk Yellow'"],
#  [],
#  [],
#  [],
#  ["'Calgary Carpet'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Blue Arrow'"],
#  ["'Blue Carpet'"],
#  ["'Blue Compact'"],
#  ["'Blue Star'"],
#  ["'Dream Joy'"],
#  [],
#  ["'Golden Flame'"],
#  ["'Golden Joy'"],
#  [],
#  [],
#  ["'Little Joanna'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Amber Glow'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Little Gem'"],
#  [],
#  [],
#  [],
#  ["'Pendula Major'"],
#  [],
#  ["'Vermont Gold'"],
#  [],
#  ["'Virgata Compacta'"],
#  [],
#  [],
#  [],
#  ["'Alberta Globe'"],
#  ["'Blue Planet'"],
#  ["'Blue Globe'"],
#  [],
#  [],
#  [],
#  ["'Dendrofarma Gold'"],
#  [],
#  ["'Jalako Gold'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Vanilla Ice'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Golden Star'"],
#  ["'Sulpher Flush'"],
#  [],
#  [],
#  [],
#  ["'Blue Diamond'"],
#  ["'Blue Mountain'"],
#  [],
#  [],
#  ["'Glauca Globosa'"],
#  ["'Glauca Pendula'"],
#  [],
#  [],
#  ["'Iseli Fastigiate'"],
#  ["'Lucky Strike'"],
#  [],
#  [],
#  [],
#  ["'Super Blue'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Compacta Glauca'"],
#  [],
#  ["'Golden Ghost'"],
#  ["'Jane Kluis'"],
#  ["'Low Glow'"],
#  ["'Oculus Draconis'"],
#  [],
#  [],
#  [],
#  ["'Compact Gem'"],
#  ["'Dolce Dorme'"],
#  ["'Green Giant'"],
#  ["'Little Dracula'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Mini Mops'"],
#  [],
#  [],
#  ["'Pal Maleter'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Sherwood Compact'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Winter Gold'"],
#  [],
#  ["'Pierrick Bregeon'"],
#  ["'Green Tower'"],
#  [],
#  ["'Marie Bregeon'"],
#  [],
#  ["'Oregon Green'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Blue Mps'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Densa Hill'"],
#  [],
#  ["'Aurea Nana'"],
#  [],
#  [],
#  ["'Joe Kozey'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Peve Minaret'"],
#  [],
#  ["'Adpressa Aurea'"],
#  [],
#  [],
#  [],
#  ["'Dovastonii Aurea'"],
#  [],
#  ["'Fastigiata Aurea'"],
#  ["'Fastigiata Robusta'"],
#  ["'Goud Elsje'"],
#  ["'Green Rocket'"],
#  ["'Little Gem'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Amber Glow'"],
#  [],
#  [],
#  ["'Degroot Spire'"],
#  [],
#  [],
#  ["'Golden Brabant'"],
#  ["'Golden Globe'"],
#  ["'Golden Tuffet'"],
#  ["'Green Egg'"],
#  ["'Janed Gold'"],
#  [],
#  [],
#  ["'Hetz Midget'"],
#  [],
#  [],
#  [],
#  ["'Malonyana Holub'"],
#  [],
#  [],
#  [],
#  ["'Pyramidalis Compacta'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Tiny Tim'"],
#  [],
#  [],
#  ["'Yellow Ribbon'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Little Boy'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Green Globe'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Cascade Gold'"],
#  ["'Crimson Princess'"],
#  ["'Dissectum Garnet'"],
#  ["'Dissectum Tamukeyama'"],
#  ["'Dissectum Viridis'"],
#  [],
#  ["'Hime Shojo'"],
#  [],
#  [],
#  ["'Jarre Schwartz'"],
#  [],
#  ["'Orange Dream'"],
#  [],
#  ["'Red Emperor'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Crimson Sentry'"],
#  ["'Esk Sunset'"],
#  ["'Prinz Handjery'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Prince Wiliam'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Red Jewel'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Atropurpurea Nana'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Chocolate Summer'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Fire Ball'"],
#  [],
#  ["'Golden Carpet'"],
#  ["'Golden Dream'"],
#  ["'Golden Ring'"],
#  ["'Golden Rocket'"],
#  ["'Green Carpet'"],
#  ["'Helmond Pillar'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Luntin Rouge'"],
#  [],
#  [],
#  ["'Orange Dream'"],
#  ["'Orange Ice'"],
#  ["'Orange Rocket'"],
#  ["'Orange Tower'"],
#  ["'Pink Perfection'"],
#  ["'Pink Queen'"],
#  [],
#  ["'Red Carpet'"],
#  ["'Red Chief'"],
#  ["'Red Column'"],
#  ["'Red Dream'"],
#  ["'Red Pillar'"],
#  ["'Red Rocket'"],
#  ["'Rose Glow'"],
#  [],
#  [],
#  ["'Summer Chocolate'"],
#  ["'Summer Sunset'"],
#  [],
#  ["'Tiny Gold'"],
#  ["'Golden Treasure'"],
#  ["'Shiloh Splash'"],
#  ["'Magical Globe'"],
#  ["'Black Knight'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Nanho Blue'"],
#  ["'Pink Cascade'"],
#  [],
#  ["'Royal Red'"],
#  [],
#  [],
#  ["'White Profusion'"],
#  [],
#  [],
#  ["'Lavender Cupcake'"],
#  [],
#  [],
#  ["'Graham Blandy'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Worcester Gold'"],
#  ["'Heavenly Blue'"],
#  ["'Dark Knight'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Alley Cat'"],
#  ["'Appalachian Red'"],
#  ["'Forest Pansy'"],
#  ["'Ruby Falls'"],
#  [],
#  ["'Vanilla Twist'"],
#  [],
#  ["'Don Egolf'"],
#  [],
#  ["'Red Joy'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Elly Moser'"],
#  ["'Fire Dance'"],
#  ["'Flacon Rose'"],
#  ["'Texas Scarlet'"],
#  [],
#  [],
#  ["'Ruby Spice'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Red Gnome'"],
#  ["'Siberian Pearls'"],
#  [],
#  ["'Sibirica Variegata'"],
#  [],
#  [],
#  ["'Green Carpet'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'China Girl'"],
#  ["'Milky Way'"],
#  [],
#  [],
#  ["'Scarlet Fire'"],
#  [],
#  [],
#  ["'Weisse Fountaine'"],
#  [],
#  [],
#  ["'Magic Flame'"],
#  ["'Midwinter Fire'"],
#  [],
#  [],
#  [],
#  ["'White Gold'"],
#  [],
#  [],
#  ["'Stellar Pink'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Purple Umbrella'"],
#  [],
#  [],
#  ["'Red Majestic'"],
#  [],
#  [],
#  [],
#  ["'Royal Purple'"],
#  [],
#  ["'Young Lady'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Coral Beauty'"],
#  [],
#  ["'Boskoop Ruby'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Mont Rose'"],
#  [],
#  ["'Strawberry Fields'"],
#  [],
#  ["'Yuki Snowsflake'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Gilt Edge'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Red Cascade'"],
#  [],
#  ["'Canadale Gold'"],
#  ["'Emerald Gaiety'"],
#  [],
#  [],
#  ["'Paloma Blanca'"],
#  ["'White Spire'"],
#  [],
#  [],
#  [],
#  [],
#  ["'The Bride'"],
#  [],
#  [],
#  ["'Aurea Pendula'"],
#  [],
#  ["'Rohan Wheeping'"],
#  [],
#  ["'Beatrix Farrand'"],
#  [],
#  ["'Golden Times'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Mck Citrine'"],
#  [],
#  [],
#  ["'Blue Shadow'"],
#  [],
#  [],
#  ["'Ron Williams'"],
#  [],
#  ["'Arnold Promise'"],
#  [],
#  [],
#  [],
#  ["'Orange Beauty'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Red Heart'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Dark Angel'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Brussels Lace'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Mega Pearl'"],
#  [],
#  [],
#  ["'Pink Diamond'"],
#  [],
#  [],
#  ["'Polar Bear'"],
#  ["'Silver Dollar'"],
#  [],
#  [],
#  [],
#  ["'Ice Crystal'"],
#  [],
#  [],
#  ["'Blue Bird'"],
#  [],
#  [],
#  [],
#  ["'Autumn Blaze'"],
#  ["'Excellent Flair'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Golden King'"],
#  [],
#  ["'Argentea Marginata'"],
#  [],
#  [],
#  [],
#  ["'Silver Queen'"],
#  ["'Glorie Dwarf'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Magical Berry'"],
#  [],
#  ["'Coral Sun'"],
#  ["'Pink Cloud'"],
#  [],
#  [],
#  [],
#  ["'Hidcote Blue'"],
#  ["'Arctic Snow'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Double Diamond'"],
#  ["'Fragrant Cloud'"],
#  [],
#  [],
#  ["'Felix Jury'"],
#  [],
#  [],
#  [],
#  ["'Honey Tulip'"],
#  ["'Heaven Scent'"],
#  ["'Green Diamond'"],
#  ["'Little Gem'"],
#  [],
#  [],
#  ["'Leonard Messel'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Red Lucky'"],
#  [],
#  ["'Solar Flair'"],
#  [],
#  ["'Alba Superba'"],
#  [],
#  ["'Heaven Scent'"],
#  ["'Rustica Rubra'"],
#  [],
#  [],
#  ["'Star Wars'"],
#  [],
#  ["'Royal Star'"],
#  [],
#  [],
#  [],
#  [],
#  ["'Yellow Bird'"],
#  ["'Yellow Lantern'"],
#  ["'Yellow River'"],
#  [],
#  [],
#  ["'Red Sentinel'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Little Spire'"],
#  ["'Blue Steel'"],
#  ["'Lacey Blue'"],
#  ["'Russian Sage'"],
#  [],
#  [],
#  ["'Belle Etoile'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Dynamo Red'"],
#  [],
#  [],
#  ["'Pink Marble'"],
#  ["'Red Robin'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Red Baron'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Pink Queen'"],
#  ["'Red Ace'"],
#  [],
#  ["'Tilford Cream'"],
#  [],
#  [],
#  [],
#  ["'Alba Plena'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Mount Vermont'"],
#  [],
#  ["'Otto Luycken'"],
#  ["'Otto Supreme'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Little Jeremy'"],
#  ["'Royal Burgundy'"],
#  [],
#  [],
#  ["'Red Column'"],
#  ["'Red Cushion'"],
#  [],
#  ["'Orange Glow'"],
#  ["'Golden Charmer'"],
#  [],
#  [],
#  ["'Curley Head'"],
#  ["'Green Dwarf'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Lace Lady'"],
#  ["'Purple Plume'"],
#  ["'Betty Ashburner'"],
#  ["'Olympic Double'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ["'Mt Aso'"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
df['A'].replace({"(\'[A-Z][a-z]+\\s[A-Z][a-z]+\'$)" : ""}, regex=True)
# Out:
# 0                igalki␞Abies alba 'Pyramidalis'
# 1                         igalki␞Abies amabilis
# 2                   igalki␞Abies balsamea 'Nana'
# 3       igalki␞Abies cephalonica 'Meyer's Dwarf'
# 4                          igalki␞Abies concolor
#                           ...
# 2981         pnącza␞Wisteria sinensis 'Caroline'
# 2982         pnącza␞Wisteria sinensis 'Prolific'
# 2983                    pnącza␞Wisteria sinensis
# 2984                         pnącza␞Vitis ripida
# 2985                   igalki␞Araucaria araucana
# Name: A, Length: 2921, dtype: object

# %%
df['A'] = df['A'].replace({'␞': ' '}, regex=True)

# %%
df
# Out:
#                                              A    B
# 0              igalki Abies alba 'Pyramidalis'  NaN
# 1       igalki Abies amabilis 'Spreading Star'  NaN
# 2                 igalki Abies balsamea 'Nana'  NaN
# 3     igalki Abies cephalonica 'Meyer's Dwarf'  NaN
# 4                        igalki Abies concolor  NaN
# ...                                        ...  ...
# 2981       pnącza Wisteria sinensis 'Caroline'  NaN
# 2982       pnącza Wisteria sinensis 'Prolific'  NaN
# 2983                  pnącza Wisteria sinensis  NaN
# 2984                       pnącza Vitis ripida  NaN
# 2985                 igalki Araucaria araucana  NaN
#
# [2921 rows x 2 columns]

# %%
df = df['A'].replace({'\xa0': ' '}, regex=True)

# %%
# Co robić z długimi liniami z średnikami?

# %%
df = df.str.split(' ', expand=True, n=3)

# %%
df
# Out:
#            0          1            2                 3
# 0     igalki      Abies         alba     'Pyramidalis'
# 1     igalki      Abies     amabilis  'Spreading Star'
# 2     igalki      Abies     balsamea            'Nana'
# 3     igalki      Abies  cephalonica   'Meyer's Dwarf'
# 4     igalki      Abies     concolor              None
# ...      ...        ...          ...               ...
# 2981  pnącza   Wisteria     sinensis        'Caroline'
# 2982  pnącza   Wisteria     sinensis        'Prolific'
# 2983  pnącza   Wisteria     sinensis              None
# 2984  pnącza      Vitis       ripida              None
# 2985  igalki  Araucaria     araucana              None
#
# [2921 rows x 4 columns]

# %%
df.columns = ['Klasa', 'Rodzina', 'Gatunek', 'Odmiana']

# %% [markdown]
# ### Edycja klas

# %%
df['Klasa'].unique()
# Out:
# array(['igalki', 'liściaste', 'róże', 'byliny', 'wrzosowate', 'trawy',
#        'iglaki', 'alejowe', 'owocowe', 'pnącza'], dtype=object)

# %%
df['Klasa'] = df['Klasa'].replace({'igalki' : 'iglaki'}, regex=True)

# %%
df['Klasa'].unique()
# Out:
# array(['iglaki', 'liściaste', 'róże', 'byliny', 'wrzosowate', 'trawy',
#        'alejowe', 'owocowe', 'pnącza'], dtype=object)

# %% [markdown]
# ### Edycja Rodzin roślin

# %%
df['Rodzina'].unique()
# Out:
# array(['Abies', 'Cedrus', 'Cephalotaxus', 'Chamaecyparis', 'Ginkgo',
#        'Juniperus', 'Larix', 'Metasequoia', 'Microbiota', 'Picea',
#        'Pinus', 'Platycladus', 'Pseudotsuga', 'Sciadopitys',
#        'Sequoiadendron', 'Taxodium', 'Taxus', 'Thuja', 'Thujopsis',
#        'Tsuga', 'Acer', 'Aesculus', 'Albizia', 'Amelanchier', 'Aralia',
#        'Aucuba', 'Berberis', 'Betula', 'Buddleja', 'Buxus', 'Callicarpa',
#        'Calycanthus', 'Carpinus', 'Caryopteris', 'Catalpa', 'Ceanothus',
#        'Cephalanthus', 'Cercidiphyllum', 'Cercis', 'Chaenomeles',
#        'Clerodendron', 'Clethra', 'Cornus', 'Corylopsis', 'Corylus',
#        'Cotinus', 'Cotoneaster', 'Crataegus', 'Cytisus', '"Cytisis',
#        'Daphne', 'Davidia', 'Deutzia', 'Edgeworthia', 'Elaeagnus',
#        'Eleutherococcus', 'Euonymus', 'Exochorda', 'Fagus', 'Forsythia',
#        'Fothergilla', 'Frangula', 'Hamamelis', 'Heptacodium', 'Hibiscus',
#        'Hippophae', 'Hydrangea', '"Hydrangea', 'Hypericum', 'Ilex',
#        'Kerria', 'Koelreuteria', 'Kolkwitzia', 'Lagerstroemia',
#        'Lavandula', 'Ligustrum', 'Lonicera', 'Magnolia', 'Mahonia',
#        'Malus', 'Osmanthus', 'Perovskia', 'Philadelphus', 'Photinia',
#        'Platanus', 'Physocarpus', 'Potentilla', 'Prunus', 'Pyracantha',
#        'Quercus', 'Ribes', 'Robinia', 'Rostrinucala', 'Rubus', 'Salix',
#        'Sambucus', 'xSinocalycanthus', 'Sophora', 'Sorbaria', 'Spiraea',
#        'Stachyurus', 'Stephanandra', 'Stewartia', 'Styrax',
#        'Symphoricarpos', 'Syringa', 'Tamarix', 'Ulmus', 'Weigela',
#        'Viburnum', 'Viburbum', 'Vinca', 'Rosa', 'Acanthus', 'Achillea',
#        'Aconitum', 'Actaea', 'Adenophora', 'Adiantum', 'Agapanthus',
#        'Agastache', 'Ajuga', 'Alcea', 'Alchemilla', 'Allium', 'Anchusa',
#        'Anemone', 'Angelica', 'Anthemis', 'Anthericum', 'Aquilegia',
#        'Arabis', 'Arenaria', 'Armeria', 'Artemisia', 'Arum', 'Aruncus',
#        'Asarum', 'Asplenium', 'Aster', 'Astilbe', 'Astrantia', 'Athyrium',
#        'Aubrieta', 'Aurinia', 'Babtisia', 'Bergenia', 'BLECHNUM',
#        'Blechnum', 'Brunnera', 'Calamintha', 'Caltha', 'Camassia',
#        'Campanula', 'Centaurea', 'Centranthus', 'Cerastium', 'Chelone',
#        'Chrysanthemum', 'Convallaria', 'Convolvulus', 'Coreopsis',
#        'Corydalis', 'Cosmos', 'Crambe', 'Crocosmia', 'Cyclamen',
#        'Cyrtomium', 'Darmera', 'Delosperma', 'Delphinium', 'Dianthus',
#        'Dicentra', 'Dictamnus', 'Digitalis', 'Disporopsis', 'Disporum',
#        'Dodecatheon', 'Doronicum', 'DRYOPTERIS', 'Dryopteris',
#        'Echinacea', 'Echinops', 'Eleocharis', 'Epilobium', 'Eremurus',
#        'Erigeron', 'Erodium', 'Eryngium', 'Erysimum', 'Eupatorium',
#        'Euphorbia', 'Fatsia', 'Filipendula', 'Fuchsia', 'Gaillardia',
#        'Galanthus', 'Galium', 'Gaura', 'Geum', 'Geranium', 'Gladiolus',
#        'Gentiana', 'Gunnera', 'Gypsophila', 'Helenium', 'Helianthemum',
#        'Helianthus', 'Helichrysum', 'Heliopsis', 'Helleborus',
#        '"Helleborus', 'Hemerocallis', 'Hepatica', 'Herniaria', 'Heuchera',
#        'xHeucherella', 'Hosta', 'Houttuynia', 'Hypsela', 'Iberis',
#        'Incarvillea', 'Iris', 'Kalimeris', 'Kirengeshoma', 'Knautia',
#        'Kniphofia', 'Lamiastrum', 'Lamium', 'Lathyrus', 'Leontopodium',
#        'Leptinella', 'Leucanthemum', 'Leucojum', 'Lewisia', 'Liatris',
#        'Ligularia', 'Lilium', 'Lillium', 'Lithodora', 'Lobelia',
#        'Lupinus', 'Lychnis', 'Lysimachia', 'Lythrum', 'Matteucia',
#        'Matteuccia', 'Mazus', 'Meconopsis', 'Mellitis', 'Mentha',
#        'Mertensia', 'Monarda', 'Myosotis', 'Nepeta', 'Nymphaea',
#        'Oenothera', 'Omphalodes', 'Origanum', 'Osmunda', 'Onopordum',
#        'Pachysandra', 'Paeonia', 'Papaver', 'Penstemon', 'Persicaria',
#        'Phlomis', 'Phlox', 'Phygelius', 'Phyllitis', 'Physalis',
#        'Physostegia', 'Platycodon', 'Podophyllum', 'Polemonium',
#        'Polygonatum', 'Polystichum', 'Primula', 'Pulmonaria',
#        'Pulsatilla', 'Rehmannia', 'Rheum', 'Rodgersia', 'Rudbeckia',
#        'Sagina', 'Salvia', 'Sanguisorba', 'Saxifraga', 'Scabiosa',
#        'Sedum', '"Sempervirum', 'Sidalcea', 'SILENE', 'Silene',
#        'Sisyrinchium', 'Solidago', 'Spigelia', 'Stachys', 'Symphytum',
#        'Tanacetum', 'Thalictrum', 'Thelypteris', 'Thymus', 'Tradescantia',
#        'Trifolium', 'Trollius', 'Waldsteinia', 'Verbascum', 'Verbena',
#        'Veronica', 'Veronicastrum', 'Viola', 'Yucca', 'Zantedeschia',
#        "Zantedeschia'Captain", 'Andromeda', 'Enkianthus', 'Empetrum',
#        'Gaultheria', 'Hebe', 'Leucothoe', 'Pernettya', 'Pieris',
#        'Rhododendron', '"Rhododendron', '"Rhododendron:', 'Rhododendron:',
#        'Skimmia', 'Acorus', 'Arundo', 'Atrophodium', 'Briza',
#        'Calamagrostis', 'Carex', 'Chasmanthium', 'Cordyline',
#        'Cortaderia', 'Dianella', 'Deschampsia', 'EQUISETUM', 'Equisetum',
#        'Eragrostis', 'Fargesia', 'Festuca', 'Ficinia', 'Glyceria',
#        'Hakonechloa', 'Helictotrichon', 'Holcus', 'Imperata', 'Juncus',
#        'Koeleria', 'Leymus', 'Liriope', 'Luzula', 'Melica', 'Miscanthus',
#        'Molinia', 'Muhlenbergia', 'Ophiopogon', 'Panicum', 'Pennisetum',
#        'Phalaris', 'Phormium', 'Phragmites', 'Phyllostachys',
#        'Pleioblastus', 'Scirpus', 'Schizachyrium', 'Semiarundinaria',
#        'Sesleria', 'Sorghastrum', 'Spartina', 'Stipa', 'Typha', 'Alnus',
#        'Cercidyphyllum', 'Fraxinus', 'Gleditsia', 'Juglans', 'Laburnum',
#        'Liquidambar', 'Liriodendron', 'Paulownia', 'Populus', 'Pyrus',
#        'Rhus', 'ROBINIA', 'Sorbus', 'Tilia', 'Aronia', 'Cydonia', 'Ficus',
#        'Fragaria', 'Lycium', 'Morus', 'Malina', 'Vaccinium', 'Vitis',
#        'Grusza', 'Krzwy', 'Jabłoń', 'Drzewa', 'Akebia', 'Aristolochia',
#        'Clematis', 'Follopia', 'Hedera', 'HUMULUS', 'Humulus',
#        'Parthenocissus', 'Wisteria', 'Araucaria'], dtype=object)

# %%
df['Rodzina'] = df['Rodzina'].replace({'Cytisis' : 'Cytisus'}, regex=True)

# %%
df['Rodzina'] = df['Rodzina'].replace({'"' : ''}, regex=True)

# %%
(df['Rodzina'].str.findall(':$').tolist())
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
df['Rodzina'] = df['Rodzina'].replace({'^x' : ''}, regex=True)

# %%
#Sinocalycanthus
df['Rodzina'].unique()
# Out:
# array(['Abies', 'Cedrus', 'Cephalotaxus', 'Chamaecyparis', 'Ginkgo',
#        'Juniperus', 'Larix', 'Metasequoia', 'Microbiota', 'Picea',
#        'Pinus', 'Platycladus', 'Pseudotsuga', 'Sciadopitys',
#        'Sequoiadendron', 'Taxodium', 'Taxus', 'Thuja', 'Thujopsis',
#        'Tsuga', 'Acer', 'Aesculus', 'Albizia', 'Amelanchier', 'Aralia',
#        'Aucuba', 'Berberis', 'Betula', 'Buddleja', 'Buxus', 'Callicarpa',
#        'Calycanthus', 'Carpinus', 'Caryopteris', 'Catalpa', 'Ceanothus',
#        'Cephalanthus', 'Cercidiphyllum', 'Cercis', 'Chaenomeles',
#        'Clerodendron', 'Clethra', 'Cornus', 'Corylopsis', 'Corylus',
#        'Cotinus', 'Cotoneaster', 'Crataegus', 'Cytisus', 'Daphne',
#        'Davidia', 'Deutzia', 'Edgeworthia', 'Elaeagnus',
#        'Eleutherococcus', 'Euonymus', 'Exochorda', 'Fagus', 'Forsythia',
#        'Fothergilla', 'Frangula', 'Hamamelis', 'Heptacodium', 'Hibiscus',
#        'Hippophae', 'Hydrangea', 'Hypericum', 'Ilex', 'Kerria',
#        'Koelreuteria', 'Kolkwitzia', 'Lagerstroemia', 'Lavandula',
#        'Ligustrum', 'Lonicera', 'Magnolia', 'Mahonia', 'Malus',
#        'Osmanthus', 'Perovskia', 'Philadelphus', 'Photinia', 'Platanus',
#        'Physocarpus', 'Potentilla', 'Prunus', 'Pyracantha', 'Quercus',
#        'Ribes', 'Robinia', 'Rostrinucala', 'Rubus', 'Salix', 'Sambucus',
#        'Sinocalycanthus', 'Sophora', 'Sorbaria', 'Spiraea', 'Stachyurus',
#        'Stephanandra', 'Stewartia', 'Styrax', 'Symphoricarpos', 'Syringa',
#        'Tamarix', 'Ulmus', 'Weigela', 'Viburnum', 'Viburbum', 'Vinca',
#        'Rosa', 'Acanthus', 'Achillea', 'Aconitum', 'Actaea', 'Adenophora',
#        'Adiantum', 'Agapanthus', 'Agastache', 'Ajuga', 'Alcea',
#        'Alchemilla', 'Allium', 'Anchusa', 'Anemone', 'Angelica',
#        'Anthemis', 'Anthericum', 'Aquilegia', 'Arabis', 'Arenaria',
#        'Armeria', 'Artemisia', 'Arum', 'Aruncus', 'Asarum', 'Asplenium',
#        'Aster', 'Astilbe', 'Astrantia', 'Athyrium', 'Aubrieta', 'Aurinia',
#        'Babtisia', 'Bergenia', 'BLECHNUM', 'Blechnum', 'Brunnera',
#        'Calamintha', 'Caltha', 'Camassia', 'Campanula', 'Centaurea',
#        'Centranthus', 'Cerastium', 'Chelone', 'Chrysanthemum',
#        'Convallaria', 'Convolvulus', 'Coreopsis', 'Corydalis', 'Cosmos',
#        'Crambe', 'Crocosmia', 'Cyclamen', 'Cyrtomium', 'Darmera',
#        'Delosperma', 'Delphinium', 'Dianthus', 'Dicentra', 'Dictamnus',
#        'Digitalis', 'Disporopsis', 'Disporum', 'Dodecatheon', 'Doronicum',
#        'DRYOPTERIS', 'Dryopteris', 'Echinacea', 'Echinops', 'Eleocharis',
#        'Epilobium', 'Eremurus', 'Erigeron', 'Erodium', 'Eryngium',
#        'Erysimum', 'Eupatorium', 'Euphorbia', 'Fatsia', 'Filipendula',
#        'Fuchsia', 'Gaillardia', 'Galanthus', 'Galium', 'Gaura', 'Geum',
#        'Geranium', 'Gladiolus', 'Gentiana', 'Gunnera', 'Gypsophila',
#        'Helenium', 'Helianthemum', 'Helianthus', 'Helichrysum',
#        'Heliopsis', 'Helleborus', 'Hemerocallis', 'Hepatica', 'Herniaria',
#        'Heuchera', 'Heucherella', 'Hosta', 'Houttuynia', 'Hypsela',
#        'Iberis', 'Incarvillea', 'Iris', 'Kalimeris', 'Kirengeshoma',
#        'Knautia', 'Kniphofia', 'Lamiastrum', 'Lamium', 'Lathyrus',
#        'Leontopodium', 'Leptinella', 'Leucanthemum', 'Leucojum',
#        'Lewisia', 'Liatris', 'Ligularia', 'Lilium', 'Lillium',
#        'Lithodora', 'Lobelia', 'Lupinus', 'Lychnis', 'Lysimachia',
#        'Lythrum', 'Matteucia', 'Matteuccia', 'Mazus', 'Meconopsis',
#        'Mellitis', 'Mentha', 'Mertensia', 'Monarda', 'Myosotis', 'Nepeta',
#        'Nymphaea', 'Oenothera', 'Omphalodes', 'Origanum', 'Osmunda',
#        'Onopordum', 'Pachysandra', 'Paeonia', 'Papaver', 'Penstemon',
#        'Persicaria', 'Phlomis', 'Phlox', 'Phygelius', 'Phyllitis',
#        'Physalis', 'Physostegia', 'Platycodon', 'Podophyllum',
#        'Polemonium', 'Polygonatum', 'Polystichum', 'Primula',
#        'Pulmonaria', 'Pulsatilla', 'Rehmannia', 'Rheum', 'Rodgersia',
#        'Rudbeckia', 'Sagina', 'Salvia', 'Sanguisorba', 'Saxifraga',
#        'Scabiosa', 'Sedum', 'Sempervirum', 'Sidalcea', 'SILENE', 'Silene',
#        'Sisyrinchium', 'Solidago', 'Spigelia', 'Stachys', 'Symphytum',
#        'Tanacetum', 'Thalictrum', 'Thelypteris', 'Thymus', 'Tradescantia',
#        'Trifolium', 'Trollius', 'Waldsteinia', 'Verbascum', 'Verbena',
#        'Veronica', 'Veronicastrum', 'Viola', 'Yucca', 'Zantedeschia',
#        "Zantedeschia'Captain", 'Andromeda', 'Enkianthus', 'Empetrum',
#        'Gaultheria', 'Hebe', 'Leucothoe', 'Pernettya', 'Pieris',
#        'Rhododendron', 'Rhododendron:', 'Skimmia', 'Acorus', 'Arundo',
#        'Atrophodium', 'Briza', 'Calamagrostis', 'Carex', 'Chasmanthium',
#        'Cordyline', 'Cortaderia', 'Dianella', 'Deschampsia', 'EQUISETUM',
#        'Equisetum', 'Eragrostis', 'Fargesia', 'Festuca', 'Ficinia',
#        'Glyceria', 'Hakonechloa', 'Helictotrichon', 'Holcus', 'Imperata',
#        'Juncus', 'Koeleria', 'Leymus', 'Liriope', 'Luzula', 'Melica',
#        'Miscanthus', 'Molinia', 'Muhlenbergia', 'Ophiopogon', 'Panicum',
#        'Pennisetum', 'Phalaris', 'Phormium', 'Phragmites',
#        'Phyllostachys', 'Pleioblastus', 'Scirpus', 'Schizachyrium',
#        'Semiarundinaria', 'Sesleria', 'Sorghastrum', 'Spartina', 'Stipa',
#        'Typha', 'Alnus', 'Cercidyphyllum', 'Fraxinus', 'Gleditsia',
#        'Juglans', 'Laburnum', 'Liquidambar', 'Liriodendron', 'Paulownia',
#        'Populus', 'Pyrus', 'Rhus', 'ROBINIA', 'Sorbus', 'Tilia', 'Aronia',
#        'Cydonia', 'Ficus', 'Fragaria', 'Lycium', 'Morus', 'Malina',
#        'Vaccinium', 'Vitis', 'Grusza', 'Krzwy', 'Jabłoń', 'Drzewa',
#        'Akebia', 'Aristolochia', 'Clematis', 'Follopia', 'Hedera',
#        'HUMULUS', 'Humulus', 'Parthenocissus', 'Wisteria', 'Araucaria'],
#       dtype=object)

# %%
df['Rodzina'] = df['Rodzina'].replace({':$' : ''}, regex=True)

# %%
#df['Rodzina'] = df['Rodzina'].replace({'^[A-Z]+$' : str.title}, regex=True)

# %%
df['Rodzina'].unique()
# Out:
# array(['Abies', 'Cedrus', 'Cephalotaxus', 'Chamaecyparis', 'Ginkgo',
#        'Juniperus', 'Larix', 'Metasequoia', 'Microbiota', 'Picea',
#        'Pinus', 'Platycladus', 'Pseudotsuga', 'Sciadopitys',
#        'Sequoiadendron', 'Taxodium', 'Taxus', 'Thuja', 'Thujopsis',
#        'Tsuga', 'Acer', 'Aesculus', 'Albizia', 'Amelanchier', 'Aralia',
#        'Aucuba', 'Berberis', 'Betula', 'Buddleja', 'Buxus', 'Callicarpa',
#        'Calycanthus', 'Carpinus', 'Caryopteris', 'Catalpa', 'Ceanothus',
#        'Cephalanthus', 'Cercidiphyllum', 'Cercis', 'Chaenomeles',
#        'Clerodendron', 'Clethra', 'Cornus', 'Corylopsis', 'Corylus',
#        'Cotinus', 'Cotoneaster', 'Crataegus', 'Cytisus', 'Daphne',
#        'Davidia', 'Deutzia', 'Edgeworthia', 'Elaeagnus',
#        'Eleutherococcus', 'Euonymus', 'Exochorda', 'Fagus', 'Forsythia',
#        'Fothergilla', 'Frangula', 'Hamamelis', 'Heptacodium', 'Hibiscus',
#        'Hippophae', 'Hydrangea', 'Hypericum', 'Ilex', 'Kerria',
#        'Koelreuteria', 'Kolkwitzia', 'Lagerstroemia', 'Lavandula',
#        'Ligustrum', 'Lonicera', 'Magnolia', 'Mahonia', 'Malus',
#        'Osmanthus', 'Perovskia', 'Philadelphus', 'Photinia', 'Platanus',
#        'Physocarpus', 'Potentilla', 'Prunus', 'Pyracantha', 'Quercus',
#        'Ribes', 'Robinia', 'Rostrinucala', 'Rubus', 'Salix', 'Sambucus',
#        'Sinocalycanthus', 'Sophora', 'Sorbaria', 'Spiraea', 'Stachyurus',
#        'Stephanandra', 'Stewartia', 'Styrax', 'Symphoricarpos', 'Syringa',
#        'Tamarix', 'Ulmus', 'Weigela', 'Viburnum', 'Viburbum', 'Vinca',
#        'Rosa', 'Acanthus', 'Achillea', 'Aconitum', 'Actaea', 'Adenophora',
#        'Adiantum', 'Agapanthus', 'Agastache', 'Ajuga', 'Alcea',
#        'Alchemilla', 'Allium', 'Anchusa', 'Anemone', 'Angelica',
#        'Anthemis', 'Anthericum', 'Aquilegia', 'Arabis', 'Arenaria',
#        'Armeria', 'Artemisia', 'Arum', 'Aruncus', 'Asarum', 'Asplenium',
#        'Aster', 'Astilbe', 'Astrantia', 'Athyrium', 'Aubrieta', 'Aurinia',
#        'Babtisia', 'Bergenia', 'BLECHNUM', 'Blechnum', 'Brunnera',
#        'Calamintha', 'Caltha', 'Camassia', 'Campanula', 'Centaurea',
#        'Centranthus', 'Cerastium', 'Chelone', 'Chrysanthemum',
#        'Convallaria', 'Convolvulus', 'Coreopsis', 'Corydalis', 'Cosmos',
#        'Crambe', 'Crocosmia', 'Cyclamen', 'Cyrtomium', 'Darmera',
#        'Delosperma', 'Delphinium', 'Dianthus', 'Dicentra', 'Dictamnus',
#        'Digitalis', 'Disporopsis', 'Disporum', 'Dodecatheon', 'Doronicum',
#        'DRYOPTERIS', 'Dryopteris', 'Echinacea', 'Echinops', 'Eleocharis',
#        'Epilobium', 'Eremurus', 'Erigeron', 'Erodium', 'Eryngium',
#        'Erysimum', 'Eupatorium', 'Euphorbia', 'Fatsia', 'Filipendula',
#        'Fuchsia', 'Gaillardia', 'Galanthus', 'Galium', 'Gaura', 'Geum',
#        'Geranium', 'Gladiolus', 'Gentiana', 'Gunnera', 'Gypsophila',
#        'Helenium', 'Helianthemum', 'Helianthus', 'Helichrysum',
#        'Heliopsis', 'Helleborus', 'Hemerocallis', 'Hepatica', 'Herniaria',
#        'Heuchera', 'Heucherella', 'Hosta', 'Houttuynia', 'Hypsela',
#        'Iberis', 'Incarvillea', 'Iris', 'Kalimeris', 'Kirengeshoma',
#        'Knautia', 'Kniphofia', 'Lamiastrum', 'Lamium', 'Lathyrus',
#        'Leontopodium', 'Leptinella', 'Leucanthemum', 'Leucojum',
#        'Lewisia', 'Liatris', 'Ligularia', 'Lilium', 'Lillium',
#        'Lithodora', 'Lobelia', 'Lupinus', 'Lychnis', 'Lysimachia',
#        'Lythrum', 'Matteucia', 'Matteuccia', 'Mazus', 'Meconopsis',
#        'Mellitis', 'Mentha', 'Mertensia', 'Monarda', 'Myosotis', 'Nepeta',
#        'Nymphaea', 'Oenothera', 'Omphalodes', 'Origanum', 'Osmunda',
#        'Onopordum', 'Pachysandra', 'Paeonia', 'Papaver', 'Penstemon',
#        'Persicaria', 'Phlomis', 'Phlox', 'Phygelius', 'Phyllitis',
#        'Physalis', 'Physostegia', 'Platycodon', 'Podophyllum',
#        'Polemonium', 'Polygonatum', 'Polystichum', 'Primula',
#        'Pulmonaria', 'Pulsatilla', 'Rehmannia', 'Rheum', 'Rodgersia',
#        'Rudbeckia', 'Sagina', 'Salvia', 'Sanguisorba', 'Saxifraga',
#        'Scabiosa', 'Sedum', 'Sempervirum', 'Sidalcea', 'SILENE', 'Silene',
#        'Sisyrinchium', 'Solidago', 'Spigelia', 'Stachys', 'Symphytum',
#        'Tanacetum', 'Thalictrum', 'Thelypteris', 'Thymus', 'Tradescantia',
#        'Trifolium', 'Trollius', 'Waldsteinia', 'Verbascum', 'Verbena',
#        'Veronica', 'Veronicastrum', 'Viola', 'Yucca', 'Zantedeschia',
#        "Zantedeschia'Captain", 'Andromeda', 'Enkianthus', 'Empetrum',
#        'Gaultheria', 'Hebe', 'Leucothoe', 'Pernettya', 'Pieris',
#        'Rhododendron', 'Skimmia', 'Acorus', 'Arundo', 'Atrophodium',
#        'Briza', 'Calamagrostis', 'Carex', 'Chasmanthium', 'Cordyline',
#        'Cortaderia', 'Dianella', 'Deschampsia', 'EQUISETUM', 'Equisetum',
#        'Eragrostis', 'Fargesia', 'Festuca', 'Ficinia', 'Glyceria',
#        'Hakonechloa', 'Helictotrichon', 'Holcus', 'Imperata', 'Juncus',
#        'Koeleria', 'Leymus', 'Liriope', 'Luzula', 'Melica', 'Miscanthus',
#        'Molinia', 'Muhlenbergia', 'Ophiopogon', 'Panicum', 'Pennisetum',
#        'Phalaris', 'Phormium', 'Phragmites', 'Phyllostachys',
#        'Pleioblastus', 'Scirpus', 'Schizachyrium', 'Semiarundinaria',
#        'Sesleria', 'Sorghastrum', 'Spartina', 'Stipa', 'Typha', 'Alnus',
#        'Cercidyphyllum', 'Fraxinus', 'Gleditsia', 'Juglans', 'Laburnum',
#        'Liquidambar', 'Liriodendron', 'Paulownia', 'Populus', 'Pyrus',
#        'Rhus', 'ROBINIA', 'Sorbus', 'Tilia', 'Aronia', 'Cydonia', 'Ficus',
#        'Fragaria', 'Lycium', 'Morus', 'Malina', 'Vaccinium', 'Vitis',
#        'Grusza', 'Krzwy', 'Jabłoń', 'Drzewa', 'Akebia', 'Aristolochia',
#        'Clematis', 'Follopia', 'Hedera', 'HUMULUS', 'Humulus',
#        'Parthenocissus', 'Wisteria', 'Araucaria'], dtype=object)

# %% [markdown]
# ### Edycja Gatunków roślin

# %%
# import żebym mógł wyświetlić wszystkie różnorodne gatunki a potem odmiany
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
#df['Gatunek'] = df['Gatunek'].replace({'^[A-Z]+$' : str.title}, regex=True)

# %%
df['Gatunek'].unique()
# Out:
# array(['alba', 'amabilis', 'balsamea', 'cephalonica', 'concolor',
#        'fraseri', 'koreana', 'lasiocarpa', 'nordmanniana', 'numidica',
#        'pinsapo', 'procea', 'veitchii', 'libani', 'deodora',
#        'harringtonii', 'lawsoniana', 'nootkatensis', 'obtusa', 'pisifera',
#        'biloba', 'chinensis', 'communis', 'conferta', 'davurica',
#        'horizontalis', 'pfitzeriana', 'pingii', 'procumbens', 'sabina',
#        'scopulorum', 'squamata', 'virginiana', 'decidua', 'kaempferii',
#        'leptolepsis', 'glyptostroboides', 'decussata', 'abies',
#        'breweriana', 'engelmannii', 'glauca', 'lutzii', 'mariana',
#        'omorica', 'orientalis', 'pungens', 'sitchensis', 'aristata',
#        'cembra', 'concorta', 'densiflora', 'flexilis', 'heldreichii',
#        'jeffreyi', 'monophylla', 'mugo', 'nigra', 'parviflora', 'peuce',
#        'ponderosa', 'pumila', 'schwerinii', 'strobus', 'sylvestris',
#        'thunbergii', 'wallichiana', 'menziesii', 'verticillata',
#        'giganteum', 'distichum', 'baccata', 'media', 'occidentalis',
#        'plicata', 'dolabrata', 'canadensis', 'campestre', 'negundo',
#        'palmatum', 'palamtum', 'platanoides', 'pseudoplatanus',
#        'shirasawanum', 'tataricum', 'hippocastanum', 'neglecta',
#        'julibrissin', "'Ballerina'", 'lamarckii', 'rotundifolia',
#        'spicata', 'elata', 'japonica', 'julianae', 'ottawensis', 'nana',
#        'pendula', 'davidii', 'wayeriana', 'microphylla', 'sempervirens',
#        'bodinierii', "'Venus'", 'betulus', 'clandonensis', 'bignonioides',
#        'thyrsiflorus', 'impressus', 'japonicum', 'speciosa', 'superba',
#        'bungei', 'alnifolia', 'controversa', "'Eddie's", 'florida',
#        'kousa', 'nuttallii', 'sanguinea', 'sericea', 'VENUS', "'Stellar",
#        'pauciflora', 'avellana', 'maxima', "'Red", 'coggygria',
#        'atropurpureus', 'bullatus', 'dammeri', 'lucidus', 'radicans',
#        'salicifolius', 'suecicus', 'monogyna', "'Boskoop", "'Hollandia'",
#        "(18'Paletto';", 'mezereum', 'involucrata', 'hybrida',
#        'purpurascens', 'rosea', 'scabra', 'chrysantha', 'angustifolia',
#        'ebbingei', 'sieboldianus', 'alatus', 'europaeus', 'fortunei',
#        'japonicus', 'phellomanus', 'planipes', 'korolkowii', 'MAGICAL',
#        "'The", 'sylvatica', "'Courtasol'", 'intermedia', "'Maluch'",
#        'viridissima', 'major', 'alnus', 'miconioides', 'syriacus',
#        'rhamnoides', 'arborescens', 'macrophylla', 'paniculata',
#        'quercifolia', 'RUNAWAY', 'serrata', "'Hidcote'", 'inodorum',
#        'polyphyllum', 'altaclerensis', 'aquifolium', 'crenata',
#        'meserveae', "'Nellie", 'indica', 'ovalifolium', 'vulgare',
#        'nitida', 'pileata', "'Betty'", "'Black", "'Cameo'", "'Cleopatra'",
#        "'Daphne'", "'Daybreak'", 'denudata', "'Elizabeth'", 'Emperor',
#        "'Felix", "'Galaxy'", "'Genie'", "'George", "'Honey", "'Heaven",
#        "'Green", 'grandiflora', 'leobnerii', "'Aphrodite'", 'lilliflora',
#        'sieboldii', "'Solar", 'soulangeana', "'Star", 'stellata',
#        "'Sunrise'", "'Suzan'", "'Susan'", "'Sunsation'", 'brooklynensis',
#        "'Yellow", "'Royalty'", "'Evereste'", "'Ola'", 'toringo',
#        'heterophyllus', 'atriplicifolia', "'Beauclerk'", "'Belle",
#        "'Biały", 'coronarius', "'Girandole'", "'Innocence'", "'Justynka'",
#        'lewisii', "'Snowbelle'", "'Rosace'", "'Starbright'", "'Lemoine'",
#        "'Virginial'", 'hispanica', 'opulifolius', 'fruticosa',
#        'cerasifera', 'cistena', 'glandulosa', 'incisa',
#        "'Kuku-shidare-zakura'", 'laurocerasus', 'serrulata', 'spinosa',
#        'triloba', 'coccinea', "'Orange", "'Golden", "'Soleil", "'Teton'",
#        'cerris', 'palustris', 'robur', 'rubra', 'alpinum', 'sanguineum',
#        'pseudoacacia', 'dependens', 'calycynoides', 'spectabilis',
#        'babylonica', 'caprea', "'Erythroflexuosa'", 'gracilistyla',
#        'matsudana', 'integra', 'irrorata', 'lanata', 'purpurea', 'repens',
#        'vinimalis', 'racemosa', 'raulstonii', 'prostrata', 'sorbifolia',
#        'arguta', 'betulifolia', 'cinerea', 'douglasii', "'Gilvers",
#        'nipponica', 'trilobata', 'vanhouttei', 'pseudocamelia',
#        'chenaultii', 'doorenbosii', 'orbiculatus', 'BLOOMERANG', 'meyeri',
#        'paluta', 'vulgaris', 'ramosissima', 'tetrandra', 'hollandica',
#        "'All", 'BLACK', "'Bristol", "'Candida'", "'Eva", "'Minuet'",
#        'middendorffiana', "'Nana", 'NAOMI', "'Newport", 'bodnantense',
#        'burkwoodii', 'carlcephalum', 'dawidii', 'lantana', "'Eskimo'",
#        'furcatum', 'opulus', 'plicatum', "'Pragense'",
#        'rhytidophylloides', 'minor', "'Alba", 'ALBA', "'Amadeus'",
#        'ANISADE', 'ASPIRIN', 'BAD', 'BASSINO', 'BONICA', "'Candia",
#        'canina', "'Chopin'", "'Dart's", "'Elfe'", "'Elfrid'", "'Escimo'",
#        "'Excelsa'", 'FAIRY', 'filipes', 'FORTUNA', 'FRIESIA', 'hugonis',
#        'INNOCENCIA', "'Irene'", "'Jan", "'Leonardo", 'MARATHON',
#        "'Merkury", 'MONICA', 'MONTANA', "'New", "'Nozomi'", 'paulii',
#        'PICCADILLY', 'pimpinellifolia', 'RED', 'rugosa', 'rubiginosa',
#        "'Scarlet", 'SCHNEEWITTCHEN', "'Sea", "'Stadt", 'SUPER',
#        "'Noatraum'", "'White", 'YELLOW', "'Abracadabra'", "'Aquarell'",
#        "'Ascot'", "'Astrid", "'Augusta", "'Bad", "'Baronesse'",
#        "'Bordeaux'", "'Bremer", "'Capri'", "'Chippendale'",
#        "'Gartentraume'", "'Gospel'", "'Grande", "'Lemon", "'Lichtkonigin",
#        "'Lovely", "'Modern", "'Naranga'", "'Nostalgie'", "'Out",
#        "'Pacific", "'Perennial", "'Pomponella'", "'Rosanna'", "'Rosarium",
#        "'Solero'", "'Uetersen", "'Voyage'", "'Wedding", "'Westerland'",
#        "'Xenia'", 'x', 'mollis', 'filipendulina', "'Little",
#        'millefolium', 'ptarnica', 'napellus', 'simplex', "'Gaudi",
#        'pedatum', 'venustum', None, "'Amsterdam'", "'Dr", "'Duinen",
#        "'Johanna'", "'Lilliput'", "'Polar", "'Rotterdam'", "'Sky",
#        "'Sunfield'", "'Twister'", 'hydrida', 'reptans', 'tenorii',
#        'molis', "'Ambassador'", "'Purple", "'Gladiator'", "'Globemaster'",
#        "'Millenium'", "'Mont", 'azurea', 'blanda', 'coronaria',
#        'hupehensis', 'leveillei', 'nemorosa', 'gigas', 'tinctoria',
#        'liliago', "'Blue", "'Crimson", "'Nora", 'caucasica', 'cordata',
#        'montana', 'maritima', 'juniperifolia', 'schmidtiana', 'italicum',
#        'dioicus', "'Johannifest'", "'Woldemar", 'eropeum', 'trichomanes',
#        'ageratoides', 'dumosus', 'alpinus', 'cordifolius', "'Lady",
#        "'Amerika'", "'Amethyst'", "'Bonn'", "'Brautschleier'",
#        "'Bressingham", "'Bumalda'", "'Catherine", "'Chocolate", "'Color",
#        "'Delf", "'Deutschland'", "'Diamant'", "'Dunes", "'Elizabeth",
#        "'Ellie'", "'Etna'", "'Europa'", "'Fanal'", "'Federsee'",
#        "'Flamingo'", "'Gloria", "'Granat'", "'Happy", "'Hennie",
#        "'Hyazinth'", "'Inshriach", "'Irricht'", "'Jacqueline'", "'Köln'",
#        "'Lollypop'", "'Maggie", "'Mainz'", "'Milk", "'Montgomery'",
#        "'Moulin", "'Nikky'", "'Paul", "'Peaches", "'Pink",
#        "'Purpurkerze'", "'Purpurlanze'", "'Rotlicht'", "'Sister",
#        "'Snowdrift'", "'Spotlight'", "'Spinell'", "'Straussenfeder'",
#        "'Superba'", "'Veronica", "'Vesuvius'", "'Vision", "'Visions'",
#        "'Weisse", 'filix-femina', 'nipponicum', 'otophorum', 'saxatilis',
#        'australis', 'cordifolia', 'Dragonfly', "'Fire", "'Flirt'",
#        "'Jelle'", "'Tubby", '-', 'spicant', 'nepeta', 'leichtlinii',
#        'carpatica', 'cochlearifolia', 'glomerata', "'Irisdescent",
#        "'Milky", 'persicifolia', 'persifolia', 'poscharskyana',
#        "'Samantha'", 'ruber', 'tomentosum', 'obliqua', "'Clara",
#        "'Duchessof", 'majalis', 'cneorum', "'Garnet'", 'granfiflora',
#        'flexuosa', 'atrosanguineus', "'Babylon'", "'Emberglow'", "'Emily",
#        "'Lucifer'", "'Mistral'", "'Twilight", 'hederifolium', 'falcatum',
#        'peltata', "'Magic", 'NEW', 'grandiflorum', 'deltoides',
#        'gratianopolitanus', 'plumarius', "'Amore", "'Burning", "'Candy",
#        'formosa', "'Ivory", "'King", 'albus', 'Digiplexis', 'valinii',
#        'pernyi', 'flavens', 'meadia', 'orientale', 'affinis', 'buschiana',
#        'championi', 'filix-mas', 'pallida', 'paradoxa', 'bannaticus',
#        'ritro', 'angustifolium', 'himalaicus', 'isabellinus',
#        "'Dunkelste", 'karvinskianus', 'variabile', "'Joe", 'maritimum',
#        'planum', 'zabelii', 'cheiri', 'cannabinum', 'dubium', 'maculatum',
#        'characias', 'ulmaria', 'nivalis', 'odoratum', 'lindheimeri',
#        "'Bohema", 'coccineum', "'Coctail", 'hybridum', 'rivale',
#        'cantabrigiense', 'cinereum', 'himalayense', 'macrorrhizum',
#        'phaeum', 'pratense', 'ROZANNE', 'sylvaticum', 'wallichianum',
#        "'Mascagni'", "'Nova", "'Plum", 'manicata', "'Salsa'",
#        "'Sombrero'", "'Double", "'Suncatcher", 'multiflorus',
#        'helianthoides', 'niger', "'Arabian", "'Arctic", "'Autumn",
#        "'Barbara", "'Bela", "'Bourbon", "'Brilliant", "'Byzantine",
#        "'Celebration", "'Chicago", "'Eenie", "'Frances", "'Frans",
#        "'Free", "'Highland", "'Irish", "'Jean", "'Joan", "'Kardynał",
#        "'Land", "'Longfields", "'Luxury", "'Maksymilian", "'Mallard'",
#        "'Mary", "'Mieczysława'", "'Moses", "'Open", "'Orchid", "'Pixie",
#        "'Sabine", "'Schnickel", "'Stella", "'Strawberry", "'Summer",
#        "'Summy", "'Total", "'Vanilla", "'Wild", "'Witch's", "'Your",
#        'nobilis', 'glabra', "'Apple", "'Beauty", "'Berry", "'Cajun",
#        "'Can", "'Champagne'", "'Cherry", "'Cinnabar", "'Coral", "'Delta",
#        "'Dew", "'Electra'", "'Forever", "'Georgia", "'Ginger",
#        "'Glitter'", "'Grape", "'Gypsy", "'Hercules'", "'Hollywood'",
#        "'Kassandra'", "'Marmalade'", "'Marvelous", 'micrantha', "'Midas",
#        "'Midnight", "'Milan'", "'Neptune'", "'Northern", "'Obsidian'",
#        "'Paprika'", "'Paris'", "'Peach", "'Peppermint", "'Rex",
#        "'Rockies", "'Silver", "'Spellbound'", "'Sugar", "'Tokyo'",
#        "'Velvet", "'World", "'Buttered", "'Copper", "'Cracked", "'Gold",
#        "'Infinity'", "'Mojito'", "'Sweet", 'Newbiscus', "'Abique", "'Age",
#        "'American", "'Antioch'", "'Big", "'Brim", "'Dream", "'Elegans'",
#        "'Fragrant", "'Francee'", "'Great", "'Guacamole'", "'Halcyon'",
#        "'Innocented'", "'June'", "'Krossa", "'Lakeside", "'Liberty'",
#        "'Minute", "'Moonstruck'", "'Night", "'Patriot'", "'Paul's",
#        'plantaginea', "'Praying", "'Rainforest", "'Raspberry", "'Regal",
#        "'School", "'Shadowland'", 'sieboldiana', "'Stiletto'", "'Sum",
#        "'Stained", 'undulata', "'Waterslide'", "'Wide", 'olympicum',
#        'reniformis', 'delavayi', 'chrysographes', 'germanica',
#        'pseudocorus', 'sibirica', 'mongolica', 'palmata', 'macedonica',
#        "'Poco", 'uvaria', "'Rocket", 'galeobdolon', 'galeobdoion',
#        'latifolius', 'squalida', 'maximum', "'Macaroon'", 'superbum',
#        'aestivum', 'cotyledon', 'dentata', 'hessei', 'przewalskii',
#        'stenocephala', "'Tigrinum'", "'Acapulto'", "'Albufeira'",
#        "'Amorosi'", "'Bonsoir'", 'martagon', "'Butter", "'Casa", "'Conca",
#        "'Corleone'", "'Crimmson", "'Dalian'", "'Dynamite'", "'Ercolano'",
#        "'Eyliner'", "'Fenice'", "'Freya'", "'Fuijan'", "'Honeymoon'",
#        "'Labrador'", "'Litouween'", "'Lizinko'", "'Menorca'", "'Mister",
#        "'Moselle'", "'Nashville'", "'Navonna'", "'Outback'", "'Pico'",
#        "'Profundo'", "'Rialto'", "'Robina'", "'Ronaldo'", "'Santander'",
#        "'Siberia'", "'Snowboard'", "'Solfarino'", "'Sorbonne'",
#        "'Striker'", "'Terrasol'", "'Topeca'", "'Tresor'", "'Zambesi'",
#        'diffusa', 'cardinalis', 'hybr.', 'hybridus', 'arkwrightii',
#        'atropurpurea', 'ciliata', 'clethroides', 'nummularia', 'punctata',
#        'salicaria', 'struthiopteris', 'betoniciflora', 'melissophyllum',
#        'aquatica', 'simplicissima', 'virginica', "'Bee-Bright'",
#        "'Bee-Free'", "'Bee-Happy'", "'Bee-Pretty'", "'Bee-Pure'",
#        'didyma', 'fistulosa', "'Schneewittchen'", 'scorpioides',
#        'faassenii', 'kubanica', 'nervosa', 'macrocarpa', 'cappadocica',
#        'verna', 'rotundifolium', 'regalis', 'acanthium', 'terminalis',
#        "'Duchesse", "'Bartzella'", "'Celebrity'", "'Henry", "'Karl",
#        "'Alertie'", "'Mme.", "'Nick", 'officinalis', "'Peter", "'Santa",
#        "'Sarah", "'Shirley", "'Ursyn", 'nudicaule', 'digitalis',
#        'amplexicaulis', 'cashmeriana', 'russeliana', 'tuberosa',
#        'subulata', 'rectus', 'aequalis', 'scolopendrium', 'peruviana',
#        'grandiflorus', "'Spotty", 'commutatum', 'hirtum', 'multiflorum',
#        'aculeatum', 'brauni', 'polyblepharum', 'rigens', 'setiferum',
#        'tsus-simense', 'atrosanguinea', 'tridentata', 'beesiana',
#        'capitata', 'denticulata', 'florindae', 'veris', 'vialii',
#        "'Moonshine'", "'Shrimps", "'Ace", 'alexandrae', 'rhabarbarum',
#        "'Bronze", 'henrici', 'AB', "'Berlin'", 'fulgida', 'laciniata',
#        "'Sunbeckia", 'argentea', 'greggii', 'guarantica', 'hakusanensis',
#        'tenuifolia', 'arendsii', 'columbaria', 'acre', "'Globe",
#        "'Herbstfreude'", 'telepchium', "'Matrona'", "'Picolette'",
#        'reflexum', 'rupestre', 'sediforme', 'sexangulare',
#        'spathulifolium', 'spectabile', "'SunSparkler", 'telephium',
#        "2023('Aqula';", 'BigSam', 'robotii', 'striatum', "'Sweety'",
#        'marilandica', "'Skrzydła", 'byzantina', 'monieri', "'Robinson's",
#        'haradjanii', 'aquilegiifolium', 'praecox', 'serphyllum',
#        "'Concord", "'Rubra'", 'rubens', 'ternata', "'Dark", "'Rosie'",
#        'bonariensis', 'rigida', 'gentianoides', 'longifolia',
#        'virginicum', "'Heartthrob'", 'cornuta', 'sororia', 'filamentosa',
#        'rostrata', 'gloriosa', "Fuego'", 'polifolia', 'campanulatus',
#        'nigrum', 'axillaris', 'SCARLETTA', 'fontanesiana', 'keiskei',
#        'mucronata', 'simsii', '(Azalea', '(AJ)', '(KH)', '(azalea',
#        '(STANDARD)', '(PREMIUM)', '2024', 'impeditum', 'yakushimanum',
#        'C', '10', "('Cosmopolitan';", 'ponticum', "'Marcel", '',
#        "4'Cunnigham's", 'calamus', 'gramineus', 'donac', 'donax',
#        'candidum', 'acutiflora', 'brachytricha', 'acutiformis',
#        'berggrenii', 'brunnera', 'buchananii', 'calotides',
#        'caryophyllea', 'comans', 'conica', "'Feather", 'flacca',
#        'flagellifera', 'grayi', 'morrowii', 'muskingumensis',
#        'oshimensis', 'pranicea', 'pseudocyperus', 'riparia', 'testacea',
#        'umbrosa', 'latifolium', 'selloana', 'tasmanica', 'coespitosa',
#        'hyemale', "'Jiuzhaigou", 'murieliae', 'robusta', 'rufa',
#        'gautierii', 'mairei', 'walberla', 'truncata', 'macra',
#        'cylindrica', 'effusus', 'ensifolius', 'inflexus', 'arenarius',
#        'muscari', 'pilosa', 'nivea', 'cilliata', 'giganteus',
#        'sacchariflorus', 'sinensis', 'arundinacea', 'caeruela',
#        'capillaris', 'planiscapus', 'virgatum', 'advena', 'alopecuroides',
#        'setaceum', 'purpureum', 'villosum', 'tenax', 'karka', 'aurea',
#        'aureosulcata', 'bissetii', 'vivax', 'pygmaeus', 'lacustris',
#        'tabernaemontanii', 'scoparium', 'fustuosa', 'autumnalis',
#        'caerulea', 'heufleriana', 'nutans', 'pectinata', 'gigantea',
#        'ichu', 'tenuissima', 'latifolia', 'minima', 'freemanii',
#        'PACIFIC', 'rubrum', 'saccharinum', 'carnea', 'glutinosa',
#        'arborea', 'papyrifera', 'utilis', 'colurna', 'excelsior',
#        'triacanthos', 'regia', 'watereri', 'styraciflua', 'tulipifera',
#        "'Spectrum'", 'kobus', "'Dolgo'", "'Fryderyk", "'Mokum'",
#        "'Professor", "'Rudolph'", 'tomentosa', 'deltroides', 'avium',
#        'eminens', 'padus', 'sargentii', 'calleryana', 'salicifolia',
#        'bimundorum', 'petraea', 'typhina', 'pdeudoacacia', 'sepulcralis',
#        'aria', 'aucuparia', 'cashmiriana', 'commixta', 'koehneana',
#        'reducta', 'europaea', 'henryana', 'platyphyllos',
#        "'Camperdownii'", "'Columella'", "'Frontier'", 'laevis',
#        'melanocapra', 'melanocarpa', 'mas', 'oblonga', 'carica',
#        '(Truskawka', 'ananasa', 'ananassa', 'vesca', 'kamtschatica',
#        'barbarum', 'domestica', 'armeniaca', 'cerasus', 'persica',
#        'niveum', 'uva-crispa', '(Porzeczka)', 'fruticosum', 'idaeus',
#        '(jeżyna)', 'corymbosum', 'vitis-idaea', 'macrocarpus', 'vinifera',
#        "'Cayuga", "'Interlaken'", "'Polo", "'Romeo'", "'Konferencja'",
#        'owocowe', 'domowa', 'quinata', 'Premium', 'baldschuanica',
#        'colchica', 'helix', 'hibernica', 'anomala', 'lupulus',
#        'quinquefolia', 'tricuspidata', 'floribunda', 'ripida', 'araucana'],
#       dtype=object)

# %% [markdown]
# ### Edycja Odmian roślin

# %%
df['Odmiana'].unique()
# Out:
# array(["'Pyramidalis'", "'Spreading Star'", "'Nana'", "'Meyer's Dwarf'",
#        None, "'Brillant'", "'Cis'", "'Dark Hill'", "'Green Carpet'",
#        "'Kohout's Icebreaker' ", "'Kristallkugel'", "'Oberon'",
#        "'Panceke'", "'Pinocchio'", "'Silberlocke'", "'Silberperle'",
#        "'Silver Show'", "'Tundra'", "'Compacta'", "'Barabits Compact'",
#        "'Golden Spreader'", "'Munsterland'", "'Glauca'", "'Aurea'",
#        "'Horstmann'", "'Bizarro'", "'Glauca Prostrata'",
#        "'Weismoor Nixie'", "'Heddergott'", "'Pendula'", "'Aurea Robusta'",
#        "'Glauca Pendula'", "'Saphire Nymph'", "'Glauca Pyramidalis'",
#        "'Horstmanns Silber'", "'Feelin Blue'", "'Karl Fuchs'",
#        "'Limeglow'", "'Fastigiata'", "'Columnaris'", "'Ellwoodii Gold'",
#        "'Imbirica Pendula'", "'Snow White'", "'Stardust'",
#        "'Ushi's Curtain'", "'Wissel's Saguaro'", "'Yvonne'",
#        "'Gloria Polonica'", "'Moonshot'", "'Aurora'", "'Gitte'",
#        "'Kamarachiba'", "'Nana Aurea'", "'Lucas'", "'Nana Gracilis'",
#        "'Tonia'", "'Tsatsumi Gold'", "'Filifera Aurea Nana'",
#        "'Filifera Nana'", "'Plumosa Compressa Nana'", "'Sungold'",
#        "'Tamara-himuro'", "'Teddy Bear'", "'Blagon' ", "'Saratoga'",
#        "'Mariken'", "'Simon'", "'Troll'", "'Tubifolia'", "'Blue Alps'",
#        "'Kurowao Gold'", "'Expansa Aureospicata'",
#        "'Expansa Aureovariegata'", "'Goldfern'",
#        "'Plumosa Aureovariegata'", "'Variegata'", "'Stricta'", "'Arnold'",
#        "'Berkshire'", "'Compressa'", "'Constance Franklin'",
#        "'Depressa Aurea'", "'Gold Cone'", "'Goldschatz'", "'Greenmantle'",
#        "'Hibernica'", "'Oblonga Pendula'", "'Repanda'",
#        "'Spotty Spreader'", "'Suecica'", "'Allgold'", "'Emerald Sea'",
#        "'Golden Wings'", "'Schlager'", "'Leningrad'", "'Andorra Compact'",
#        " ICEE BLUE  Monber'", "'Andorra Variegata'", "'Blue Chip'",
#        "'Blue Forest'", "'Glacier'", "'Golden Carpet'", "'Pancake'",
#        "'Prince of Wales'", "'Wiltonii'", "(x) 'Golden Saucer'",
#        "(x) 'Goldkissen'", "(x) 'Gold Star'", "(x) 'King of Spring'",
#        "(x) 'Mint Julep'", "(x) 'Mordigan Gold'", "(x) 'Old Gold'",
#        "(x) 'Pfitzeriana Aurea'", "(x) 'Pfitzeriana Compacta'",
#        "(x) 'Pfitzeriana Glauca'", "(x) 'Roussour'", "'Hulsdonk Yellow'",
#        "'Loderii'", "'Calgary Carpet'", "'Hicksii'", "'Tamariscifolia'",
#        "'Blue Arrow'", "'Blue Carpet'", "'Blue Compact'", "'Blue Star'",
#        "'Dream Joy'", "'Floreant'", "'Golden Flame'", "'Golden Joy'",
#        "'Holger'", "'Hunnentorp'", "'Little Joanna'", "'Meyeri'",
#        "'Hetz'", "'Diana'", "'Amber Glow'", "GOLDRUSH 'Ogon'",
#        "'Acrocona'", "'Barryi'", "'Cruenta'", "'Cupressina'",
#        "'Echiniformis'", "'Formanek'", "'Frohburg'", "'Inversa'",
#        "'Little Gem'", "'Nidiformis'", "'Ohlendorffii'", "'Push'",
#        "'Pendula Major'", "'Tompa'", "'Vermont Gold'", "'Virgata'",
#        "'Virgata Compacta'", "'Will's Zwerg'", "'Alberta Globe'",
#        "'Blue Planet'", "'Blue Globe'", "'Cinderella'", "'Conica'",
#        "'Daisy's White'", "'Dendrofarma Gold'", "'Jalako Gold'",
#        "'Rainbow's End'", "'Sander's Blue'", "'Laurin'", "'Vanilla Ice'",
#        "(x) 'Machala'", "'Freya'", "'Karel'", "'Bruns'", "'Pimoko'",
#        "'Zuckerhut'", "'Aureospicata'", "'Golden Star'",
#        "'Sulpher Flush'", "'Summergold'", "'Baby Blue Eyes'",
#        "'Białobok'", "'Blue Diamond'", "'Blue Mountain'", "'Edith'",
#        "'Glauca Globosa'", "'Hoopsii'", "'Hoto'", "'Iseli Fastigiate'",
#        "'Lucky Strike'", "'Mecky'", "'Montgomery'", "'Moerheim'",
#        "'Super Blue'", "'Thuem'", 'var.glauca', "'Waldbrunn'", "'Nana",
#        "'Tenas'", "'Compacta Glauca'", "'Taylor's Sunburst'",
#        "'Golden Ghost'", "'Jane Kluis'", "'Low Glow'",
#        "'Oculus Draconis'", "'Vanderwolf's Pyramid'", "'Pygmea'",
#        "'Compact Gem'", "'Dolce Dorme'", "'Green Giant'",
#        "'Little Dracula'", "'Malinki'", "'Satellit'", "'Smidtii'",
#        "'Joppi'", "'Allgäu'", "'Benjamin'", "'Carsten'", "'Cyrzan'",
#        "'Gnom'", "'Goldstar'", "'Grüne Kugel'", "'Grüne Welle'",
#        "'Hnízdo'", "'Humpy'", "'Jezek'", "'Jacobsen'", "'Klostergrun'",
#        "'Kobold'", "'Krauskopf'", "'Litomyšl'", "'Mini Mops'", "'Mops'",
#        "'Ophir'", "'Pal Maleter'", "'Peterle'", "'Picobello'",
#        "'Pigelmee'", "'Pumuckel'", "'Rigi'", "'Sherwood Compact'",
#        'subsp.mugo', "'Sunshine'", 'var.pumilio', "'Varella'",
#        "'Winter Gold'", "'Wintersonne'", "BREPO 'Pierrick Bregeon'",
#        "'Green Tower'", "'Komet'", "'Marie Bregeon'", "'Oregon Green'",
#        "'Richard'", 'subsp.nigra', "'Aro-Kawa'", "'Aui'", "'Fukai'",
#        "'Goldilocks'", "'Negishi'", "'Ogon-janome'", "'Ryu-ju'",
#        "'Shoon's Bonsai'", "'Tanima-no-yuki'", "'SDL2'", "'Blue Mps'",
#        "'Drayer's Dwarf'", "'Santis'", "(x) 'Wiethorst'", "'Louie'",
#        "'Albijns'", "'Watereri'", "'Ogon'", "'Densa Hill'", "'Zebrina'",
#        "'Aurea Nana'", "'Fletcheri'", "'Joe Kozey'", "'Picola'",
#        "'Healty Mammoth One'", "'Healty Mammoth Two'",
#        "'Healty Mammoth Three'", "'Peve Minaret'", "'Adpressa Aurea'",
#        "'Anny's Dwarf'", "'David'", "'Dovastoniana'",
#        "'Dovastonii Aurea'", "'Fastigiata Aurea'", "'Fastigiata Robusta'",
#        "'Goud Elsje'", "'Green Rocket'", "'Nissen's Prasident'",
#        "'Overeynderi'", "'Repandens'", "'Semperaurea'", "(x) 'Fairview'",
#        "(x) 'Farmen'", "(x) 'Hicksii'", "(x) 'Hillii'", "(x) 'Viridis'",
#        "(x) 'Groenland'", "(x) 'Wojtek'", "'Brabant'", "'Danica'",
#        "'Degroot Spire'", "'Filiformis'", "'Globosa'", "'Golden Brabant'",
#        "'Golden Globe'", "'Golden Tuffet'", "'Green Egg'",
#        "GOLDEN SMARAGD 'Janed Gold'", "'Janed Gold'('Golden Smaragd')",
#        "'Jantar'", "'Hetz Midget'", "'Hoseri'", "'Konfettii'", "'Hoveyi'",
#        "'Malonyana Holub'", "'Miky'", "'Mirjam'", "'Mr. Bowling Ball'",
#        "'Pyramidalis Compacta'", "'Salland'", "'Smaragd'", "'Spiralis'",
#        "'Stolwijk'", "'Tiny Tim'", "'Waterfield'", "'Woodwardii'",
#        "'Yellow Ribbon'", "'Zmatlik'", "'Atrovirens'",
#        "'Atrovirens' PROMOCJA", "'4Ever'  GOLDY", "'Can-Can'",
#        "'Excelsa'", "'Emerald'", "'Gerdeland'", "'Kórnik'",
#        "'Kruger's Beauty'", "'Martin'", "'Little Boy'", "'Whipcord'",
#        "'Cole's Prostrate'", "'Green Globe'", "'Jeddeloh'",
#        "'Popelewski'", "'Nanum'", "'Carnival'", "'Aureomarginatum'",
#        "'Flamingo'", "'Anne-Irene'", "'Atropurpureum'", "'Beni-maiko'",
#        "'Bloodgood'", "'Cascade Gold'", "'Crimson Princess'",
#        "'Dissectum Garnet'", "'Dissectum Tamukeyama'",
#        "'Dissectum Viridis'", "'Fireglow'", "'Hime Shojo'",
#        "'Koto-no-ito'", "'Inaba-shidare'", "'Jarre Schwartz'",
#        "'Mikawa-yatsubusa'", "'Orange Dream'", "'Osakazuki'",
#        "'Red Emperor'", "'Sangokaku'", "'Shishigashira'",
#        "'Skeeter's Broom'", "'Tamukeyama'", "'Trompenburg'",
#        "'Crimson Sentry'", "'Esk Sunset'", "'Prinz Handjery'",
#        "'Simon-Louis Freres'", "'Aureum'", "'Flame'", "'Gimborn's Pride'",
#        "'Monstrosa'", "'Erythroblastos'", "Chocolate Fountain 'NCAJ1'",
#        "'Prince Wiliam'", "'Edelweiss'", "'Crotonifolia'",
#        "(x) 'Parkjuweel'", "(x) 'Red Jewel'", "(x) 'Superba'",
#        "'Admiration'", "'Atropurpurea'", "'Atropurpurea Nana'",
#        "'Bagatelle'", "BONANZA GOLD 'Bogozam'", "'Carmen'",
#        "'Chocolate Summer'", "'Concorde'", "'Coral'", "'Dart's Red Lady'",
#        "'Erecta'", "'Fire Ball'", "'Golden Dream'", "'Golden Ring'",
#        "'Golden Rocket'", "'Helmond Pillar'", "'Inspiration'",
#        "'Kelleris'", "LIMONCELLO 'BailErin'", "'Luntin Rouge'", "'Maria'",
#        "'Natasza'", "'Orange Ice'", "'Orange Rocket'", "'Orange Tower'",
#        "'Pink Perfection'", "'Pink Queen'", "'Powwow'", "'Red Carpet'",
#        "'Red Chief'", "'Red Column'", "'Red Dream'", "'Red Pillar'",
#        "'Red Rocket'", "'Rose Glow'", "'Rose Rocket' ", "'Ruby Star' ",
#        "'Summer Chocolate'", "'Summer Sunset'", "'Sunsation'",
#        "'Tiny Gold'", "'Golden Treasure'", "'Shiloh Splash'",
#        "'Magical Globe'", "'Black Knight'",
#        "'Butterfly Candy Little Lila'", "'Butterfly Candy Little Pink'",
#        "'Butterfly Candy Little Purple'", "'Butterfly Candy Little Ruby'",
#        "'Butterfly Candy Little Sweetheart'",
#        "'Butterfly Candy Little White'", "'Dreaming White' ",
#        'FLOWER POWER', "FLUTTERBY PINK 'Podaras9'",
#        "FREE PETITE SNOW WHITE 'Podaras'", "'Magenta Munchkin' ",
#        "'Nanho Blue'", "'Pink Cascade'", "'Prince Charming' ",
#        "'Royal Red'", "SUGAR PLUM 'Lonplum'", 'TRICOLOR',
#        "'White Profusion'", "'Wisteria Lane' ", "(x) 'Sungold'",
#        "'Lavender Cupcake'", "'Faulkner'", "'Graham Blandy'", "'Elegans'",
#        "'Profusion'", "'Monumentalis'", "(x) 'Worcester Gold'",
#        "(x) 'Heavenly Blue'", "(x) 'Dark Knight'", "(x) 'White Suprise' ",
#        'var.repens', "'Victoria'", "'Ace of Hearts'", "'Alley Cat'",
#        "'Appalachian Red'", "'Forest Pansy'", "'Ruby Falls'",
#        "THE RISING SUN 'JN2'", "'Vanilla Twist'", "'Avondale'",
#        "'Don Egolf'", "'Red Joy'", "'Sargentii'", "'Yukigoten'",
#        "(x) 'Cameo'", "(x) 'Clementine'", "(x) 'Crimson & Gold'",
#        "(x) 'Elly Moser'", "(x) 'Fire Dance'", "(x) 'Flacon Rose'",
#        "(x) 'Texas Scarlet'", "'Hummingbird'", "'Ruby Spice'",
#        "BATON ROUGE 'Minbat'", "'Elegantissima'", "'Gouchaultii'",
#        "IVORY HALO  'Baihalo'", "'Kesselringii'", "'Red Gnome'",
#        "'Siberian Pearls'", "'Sibirica'", "'Sibirica Variegata'",
#        "'Pagoda'", "White Wonder'", "'Rainbow'", "'Rubra'",
#        "'Bultinck's Giant Flower'", "'Cappucino'", "'China Girl'",
#        "'Milky Way'", "'Robert's Select'", "'Satomi'", "'Scarlet Fire'",
#        "'Schmetterling'", 'var. chinensis', "'Weisse Fountaine'",
#        "'Ascona'", "'Magic Flame'", "'Midwinter Fire'", "'Flaviramea'",
#        "'Hedgerow's Gold'", "'Kelseyi'", "'White Gold'", "'KN30 8'",
#        " 'KN30 8'", "Pink'", "'Anny's Purple Dream'", "'Concorta'",
#        "'Purple Umbrella'", "'Twister'", "'Purpurea'", "Majestic'",
#        "'Grace'", "'Lilla'", "'Golden Spirit' ", "'Royal Purple'",
#        "'Young Lady'", "'Variegatus'", "'Major'", "'Mooncreeper'",
#        'var. radicans', "'Queen of Carpets'", "'Streib's Findling'",
#        "'Eichholz'", "'Parkteppich'", "(x) 'Coral Beauty'", "Ruby'",
#        '18\'Golden Sunlight\'; 18\'Allgold\'; 18\'Albus\'; 18\'Luna\'; 18\'Boskoop Ruby\')"',
#        "(x) 'Mont Rose'", "(x) 'Pink Pom-Pom'", "(x) 'Strawberry Fields'",
#        "(x) 'Yuki Cherry Blossom'", "(x) 'Yuki Snowsflake'",
#        "'Kalmiflora'", "(x) 'Campanulata'", "'Candidissima'", "'Plena'",
#        "'Grandiflora'", "(x) 'Compacta'", "(x) 'Gilt Edge'",
#        "'Compactus'", "'Red Cascade'", "'Coloratus'", "'Canadale Gold'",
#        "'Emerald Gaiety'", "'Emerald'n Gold'", "'Aureus'",
#        "'Paloma Blanca'", "'White Spire'", "SPRINGTIME  'Kolmaspirit'",
#        "Bride'", "'Atropunicea'", "'Aurea Pendula'", "'Mercedes'",
#        "'Rohan Wheeping'", "MAREE D'OR", "(x) 'Beatrix Farrand'",
#        "(x) 'Flojor'", "(x) 'Golden Times'", "(x) 'Lynwood'",
#        "(x) 'Spectabilis'", "(x) 'WEEK-END 'Courtalyn' ",
#        "CITRUS SWIZZLE 'Mck Citrine'", "'Kumsum'", "(x) 'Blue Shadow'",
#        "'Asplenifolia'", "FINE LINE 'Ron Williams'", "(x) 'Aphrodite'",
#        "(x) 'Arnold Promise'", "(x) 'Diane'", "(x) 'Feuerzauber'",
#        "(x) 'Jelena'", "(x) 'Orange Beauty'", "(x) 'Pallida'",
#        "BLUE CHIFFON 'Notwood3'",
#        "FLOWER TOWER PURPLE 'Gandini Santiago '",
#        "CHINA CHIFFON 'Bricutts' ", 'LAVENDER CHIFFON', "'Red Heart'",
#        'WHITE CHIFFON', "'Hergo'", "'Hikul'", "'Pollmix'", "'Anabelle'",
#        "CANDYBELLE BUBBLEGUM 'GRHYAR1407'", "PINK ANABELLE 'NCHA2'",
#        "STRONG ANABELLE 'Abetwo'", "SWEET ANABELLE 'NCHA4'",
#        "CANDYBELLE MARSHMALLOW 'GRHYAR1406' ",
#        '(\'Atlantica\'; \'Bodensee\'; \'King George V\'; \'Libelle\')"',
#        "'Bela' (niebieska)",
#        "BELLA PESCHE 'Hore1644' (biało-zielonkawo-różowawa)",
#        "BLACK DIAMONDS DARK ANGEL 'Dark Angel'", "'Bodensee' (niebieska)",
#        "'Charming Colleciot' (Alice / Claire / Sophia)",
#        'classic (Adula / Curly Sparkle)',
#        "'Doppio Bianco' (biała  pełna)",
#        "'Doppio Nuvola' (jasny róż  pełna)",
#        "'Dutch Ladies Selma' (intensywny róż)", "'Dutch Ladies Sylvia'",
#        "'Early Blue' (niebieska)", 'PREMIUM', 'FLAIR & FLAVOUR ',
#        "'Freudenstein' (ciemny róż)", "'Leuchtfeuer' (czerwono-różowa)",
#        "'Red Baron'(czerono-różowa)",
#        "REMBRANDT 'Dolce Chic'' ( różówo-zielona)",
#        "REMBRANDT 'Elegant Rosa' (blado różówo-zielona)",
#        "REMBRANDT 'Rosso Glory' (c.różowo-zielona)",
#        "REMBRANDT 'Vibrant Verde' (zielona)", "'Schneeball' (biała)",
#        "'Selma' (intensywny róż)", "'Snowball' (biała)",
#        "'Wudu' :-((  (biało-zielona)", "'Brussels Lace'", "BOBO 'ILVObo'",
#        "'Bombshell'", "CANDLELIGHT  'Hpopr013'",
#        "DART'S LITTLE DOT 'Darlido'", 'DIAMANT ROUGE \'Rendia"""',
#        "DIAMANTINO 'Ren 101'", "FRAISE MELBA 'Renba'",
#        "GRAFFITI 'ROU201406'", 'in stam', "'Limelight'",
#        "LITTLE LIME 'Jane'", 'LITTLE SPOOKY ‘GRH’',
#        "'Living Pinky Primise'", "'Living Sugar Rush'",
#        "MAGICAL CANDLE 'Bokraflame' synomin 'Coctail'",
#        "MAGICAL FIRE 'Bokraplume' ", "MAGICAL FLAME 'Borkratorch'",
#        "MAGICAL HIMALAYA 'Kolmahima'", "MAGICAL MOONLIGHT 'Kolmagino'",
#        "MAGICAL VESUVIO 'Kolmavesu'", "MEGA MINDY 'Ilvomindy'",
#        "'Mega Pearl'", "MOJITO 'GRH'", "'Phantom'", "'Pink Diamond'",
#        "PINKACHU 'Smhppinka'", "'PINKY WINKY 'DVPPinky'", "'Polar Bear'",
#        "'Silver Dollar'", "SKYFALL  'Frenne' ",
#        "SUNDAE FRAISE 'Rensun'cov", "VANILLE FRAISE   'Renhy'cov",
#        "'Ice Crystal'", "BRIDE SNOW WHITE 'USCHYD0405' ",
#        "AVELROZ 'Dolmyf' ", "'Blue Bird'", "DAREDEVIL 'JPD 01'",
#        "'Intermedia'", "'Autumn Blaze'", "'Excellent Flair'", "'Loke'",
#        "MAGICAL BEAUTY 'Kolmbeau'", "MAGICAL SUNSHINE 'Kolmasun'",
#        "'Grandiflorum'", "(x) 'Golden King'", "'Alaska'",
#        "'Argentea Marginata'", "'Golden van Tol'", "'Ingramii'",
#        "'J.C.van Tol'", "'Silver Queen'", "'Glorie Dwarf'", "'Stokes'",
#        "(x) 'Blue Angel' (typ żeński)", "(x) 'Blue Maid' (typ żeński)",
#        "(x) 'Blue Prince' (typ męski)",
#        "(x) 'Blue Princess' (typ żeński)", "(x) 'Casanova'  (typ męski)",
#        "(x) 'Heckenblau' (typ męski)", "(x) 'Heckenfee' (typ żeński)",
#        "(x) 'Heckenpracht' (typ żeński)", "(x) 'Heckenstar'  (typ męski)",
#        "(x) LITTLE RESCAL 'Mondo'", "R. Stevens'", "R.Stevens'",
#        "'Magical Berry'", "'Pleniflora'", "'Coral Sun'", "'Pink Cloud'",
#        '(w odmianach)', "'Munstead'", "'Hidcote Blue'", "'Arctic Snow'",
#        "'Aromance' White", "'Elegant'", "Tulip' ('Jurmag 1' )",
#        "'Double Diamond'", "'Fragrant Cloud'", "('MGEMP_2012 )", "Jury'",
#        "Henry Kern'", "Tulip'", "Scent'", "Diamond'",
#        "(x) 'Mag's Pirouette'", "(x) 'Leonard Messel'", "(x) 'Merrill'",
#        "(x) 'Wildcat'", "'Nigra'", "as Red'", "Lucky'", "Flair'", '(x)',
#        "(x) 'Alba Superba'", "(x) 'Alexandrina'", "(x)  'Heaven Scent'",
#        "(x) 'Rustica Rubra'", "(x) 'Satisfaction'", "Wars'",
#        "'Royal Star'", "(x) 'Yellow Bird'", "Lantern'", "River'",
#        "'Apollo'", "Sentinel'", "'Tina'", "'Goshiki'", "'Little Spire'",
#        "'Blue Steel'", "'Lacey Blue'", "'Russian Sage'", "'Rocketmann' ",
#        "Etoile'", "Karzeł'", "'Waterton'", "CARRÉ ROUGE 'Mandarino'",
#        "'Dynamo Red'", "'Little Red Robin'", "PINK CRISPY 'Oploo 5'",
#        "'Pink Marble'", "'Red Robin'", "(x) 'Alphen's Globe'",
#        "DIABLE d'OR 'Mindia'", "'Diabolo'", "LADY IN RED 'Tuilad' ",
#        'LITTLE ANGEL ‘Hoogii016’', "'Luteus'", "LITTLE JOKER 'Hoogi021'",
#        "'Nugget'", "'Red Baron'", "SUMMER WINE 'Seward'",
#        "BELLA BIANCA 'Hachbianca' ", "BELLA LINDSEY 'Hendlin'",
#        'BELLA ROSA', "BELLA SOL 'Hanchdon'", "BELLISSIMA 'Hachlis'",
#        "'Daydawn'", "'Goldfinger'", "'Goldteppich'",
#        "MARIAN RED ROBIN   'Marrob'", "'Red Ace'", "'Tangerine'",
#        "'Tilford Cream'", "(x) 'Nigra'", "'Alba Plena'", "'Kojou-no-mai'",
#        " BONAPARTE 'Flippi01'", " 'Caucasica'", " ETNA  'Anbri' ",
#        "'Ani' ", "'Antonius' ", "'Chameleon'", "'Elly' VERSTRA", "'Gajo'",
#        "GENOLIA 'Mariblon'", "'Herbergii'", "'Mano'", "'Mount Vermont'",
#        "'Novita'", "'Otto Luycken'", "'Otto Supreme'", "'Rotundifolia'",
#        "TITAN  'Rentan'", 'var.depressa', "'Amanogawa'", "'Kanzan'",
#        "'Little Jeremy'", "'Royal Burgundy'", "'Red Cushion'",
#        'var.kuntayi', "Glow'", "Charmer'", "d'Or'", "'Curley Head'",
#        "'Green Dwarf'", "'Isabel'", "'Alnarp'", "'Timuki'", "'Haaren'",
#        "'Schmidt'", "'King Edward VII'", "'Frisia'",
#        "'TWISTY BABY 'Lace Lady'", "'Purple Plume'", "'Betty Ashburner'",
#        "'Olympic Double'", "'Chermesina'", "'Vitellina'", "'Tortuosa'",
#        "'Kilmarnock'", "'Mt Aso'", "'Hakuro-nishiki'", 'var. nitida',
#        "BLACK BEAUTY 'Gerda'", "BLACK LACE'", "BLACK TOWER 'Eiffel1'",
#        "GOLDEN TOWER 'Jdeboer001'", "'Madonna'", "'Pulverenta'",
#        "'Thundercloud'", "'Plumosa Aurea'", "'Sutherland Gold'",
#        "'Hartlage Wine'", "'Little Baby'", "'Sem'", "'Tor'",
#        "(x) 'Grefsheim'", 'var.menzesii', "Miles'", "'Albiflora'",
#        "'Anthony Waterer'", "'Anthony Waterer Sapho'", "'Candlelight'",
#        "'Crispa'", "'Dart's Red'", 'DOUBLE PLAY GOLD', "'Froebelii'",
#        "'Genpei' (='Shirobana')", "'Golden Princess'", "'Goldflame'",
#        "'Goldmound'", "'Japanese Dwarf'", "'Little Princess'",
#        "'Macrophylla'", "MAGIC CARPET 'Walbuma'",
#        "MAGNUM ROSE 'Brolanspi'", "'Manon'", "'Sparkling Carpet'",
#        "'Sparkling Champagne'", "'Halward's Silver'", "'June Bride'",
#        "'Snowmound'", "WHITE CARPET 'Gelspir'", "(x) 'Gold Fountain'",
#        "'Celina'", "'Big Cascade'", "(x) 'Brian de Soleil'",
#        "(x) 'Hancock'", "(x) MAGICAL GALAXY 'Kolmgala'",
#        "(x) MAGICAL CANDY 'Kolmcan'", "(x) 'White Hedge'",
#        "'Pink Perfume'", "'Dark Purple'", "'Palibin'", "'Superba'",
#        "'Miss Kim'", "'Beauty of Moscow'", "'Belle de Nancy'",
#        "'Charles Joy'", "'Katherine Havemeyer'",
#        "LUDWIG SPAETH 'Andenken an Ludwig Späth'", "'Michel Buchner'",
#        "'Mme Lemoine'", "'Sensation'", "(x) 'Wredei'", "Summer Red' ",
#        "& WHITE  'Courtacad1'", "Rathke'", "ALL SUMMER MONET 'Verweig 8'",
#        "'Follis Purpureis'", "'Minuet'", "FRENCH LACE 'Brigela'",
#        "MAGICALRAINBOW 'Kolmagira'cov", "MIDNIGHT WINE 'Elvera'",
#        "MINOR BLACK 'Verweig3'", "MONET 'Verweig'", "'Nana Purpurea'",
#        "'Suzanne'", "WINE & ROSES' Alexandra'", "'Wings of Fire'",
#        "Variegata'", "CAMPBELL 'Bokrashine' ", "Red'", "Prince'",
#        "(x) 'Dawn'", "'Aureovariegata'", "'Compactum'", 'Roseum',
#        "'Roseum'", "'Kilimandjaro' ", "KILIMANDJARO SUNRISE 'Jww5'",
#        "'Lanarth'", "'Mariesii'", "'Pink Beauty'", "'Pink Sensation'",
#        "'Rowallane'", "'Shasta'", "'Tennessee'", "'Watanabe'", "'Alba'",
#        "'Alba Variegata'", "'Bowles Cunningham'", "'Elisa'",
#        "'Gertude Jekyll'", "'Illumination'", "'Moonlit'",
#        "'Ralph Shugart'", "Fairy'", "MEIDILAND 'Meiflopan'",
#        "'Wekvossutono'", "ROSE 'Taniripsa' ", "BIRNBACH 'Korpancom'",
#        "'Kormixal'", "Forest Rose'", "82 'Meidomonac'", "Meidiland'",
#        "Defender'", "DANCE 'Harward'", "'Kiftsgate'", "'Kortuna'",
#        "'Korresia'", "'Korenbon'", "Paweł II'", "da Vinci'",
#        "'Bokrathon'", "2000'", "'Tanakinom'", "'Royal Occasion'", "Dawn'",
#        "'Macar'", "FAIRY 'Moredfar'", "Leonardo da Vinci'",
#        "'Moje Hammarberg'", "'Blanc Double de Coubert'",
#        "DWARF PAVEMENT 'Handavem'", "GELBE DAGMAR HASTRUP 'Moryelrug'",
#        "DAGMAR HASTRUP 'Fru Dagmar Hastrup'", "'Hansa'",
#        "PINK ROADRUNNER 'Uhlarium'", "POLAREIS 'Stronin'",
#        "PURPLE PAVEMENT 'Hanpavpu'", "PURPLE ROADRUNNER 'Uhlpurp'",
#        "ROSA ZWERG 'Handavem'", "'Roseraie de I'Hay'",
#        "ROTE HANNOVER 'Bokrahan'", "'Rotes Meer'", "'Scabrosa'",
#        "SCHNEEKO 'Hansnovem'", "SMART ROADRUNNER 'Uhlrutida'",
#        "SNOW PAVEMENT 'Hansnovem'", "WHITE ROADRUNNER 'Uhlsylt'",
#        "'Korbin'", "Foam'", "Rom'", "DOROTHY 'Heldoro'", "New Dawn'",
#        "FAIRY 'Poulfair'", "'Ritausma'", "Grafin von Hardenberg'",
#        "Luise'", "Birnbach'", "Stadmusikanten'", "Amore'", "Rokoko'",
#        "Lucia'", "Art'", "of Rosenheim'", "Blue'", "Uetersen'",
#        "Klosterrose'", "Piano'", "hybrida 'Whitewater'  ",
#        "'tasmanian Angel'  ", "'Parkers'", "Moonshine'", "'Apfelblüte'",
#        "'Cerise Queen'", "'Paprika'", "'Pretty Belinda'", "'Red Velvet'",
#        "'Skysail Yellow' ", "'Summer Pastels'", "'Terracotta'",
#        "'Nana Compacta'", "'Album'", "'Black Negligee' ", "Violet'",
#        "Buddhist'", "in Black'", "Brouwer'", "Brugge White'", "Ice'",
#        "'Black Adder'", "'Blue Fortune'", "'Danish Deilight' ",
#        "'Blue Boa'  ", "'Alabaster'", "'Little Adder' ",
#        "'Black Scallop'", "'Blueberry Muffin'", "'Burgundy Glow'",
#        "'Gold Chang' ", "'Sparkler'", "'Princess Nadia' ", "'Select'",
#        "Sensation'", "Everest'", "'Loddon Royalist'", "'Margarete'",
#        "'Pretty Lady Julia'", "'Pretty Lady Suzan'", "'Prinz Heinrich'",
#        "'Splendens'", "(x) 'Andrea Atkinson'", "(x) 'Bressingham Glow'",
#        "(x) 'Hadspen Abundace'", "(x) 'Honorine Jobert'",
#        "(x) 'Königin Charlotte'", "(x) 'Lorelei'", "(x) 'Mont-rose'",
#        "(x) 'Pamina'", "(x) 'Serenade'", "(x) 'Whirlwind'",
#        "'Sauce Hollandaise'", "'E.C. Buxton'", "Star'", "Barlow'",
#        "'Black Barlow'", "'Blue Barlow'", "'Rose Barlow'", "'Ruby Port'",
#        "'Rose Delight'", "'Sun King'", "'Mont Blanc'",
#        "'New Zealand Form'", "'Armada Rose'", "'Nifty Thrifty'",
#        "'Silver Mound'", "Meier'", "'Ashvi'", "'Starshine' ",
#        "'Island Bahamas' ", "'Island Samoa' ", "'Island Tonga' ",
#        "'X Pink'", "'Little Carlow'", "in Blue'", "Beauty'", "Deneuve'",
#        "Shogun'", "Flash'", "Lace'", "Future'", "van Veen'", "Purpurea'",
#        "Spirit'", "Graafland'", "Vision in Pink'", "Daley'", "and Honey'",
#        "Rouge'", "Gaarder'", "and Cream'", "Lighting'", "Skyscraper'",
#        "Theresa'", "Klose'", "in Pink'", "in Red'", "in White'",
#        "Inferno'", "Vulcano'", "Gloria'", "'Astra White'", "'Astra Red'",
#        "'Roma'", "'White Angel'", "'Lady in Red'", "'Rotsiel'",
#        "'Burgundy Lace' ", "'Metalicum'", "'Pewter Lace' ",
#        "'Ursula's Red'", "'Okanum'", "(x) 'Audrey Blue Shades'",
#        "(x) 'Audrey Purple Shades'", "(x) 'Audrey Red'",
#        "(x) 'Audrey Sky Blue'", "(x) 'Axcent Burgundy' ",
#        "(x) 'Axcent Deep Purple'", "(x) 'Axcent Light Blue'",
#        "(x) 'Glacier Blue'", "'Rotblum'", "'Angel Kiss'", "'Sakura'",
#        "& Ice'", '', "Dragonfly'", "White'", "Andrews'", 'PODRZEŃ',
#        "'Alexander's Great'  ", "'Betty Bowring'", "'Jack Frost'",
#        "'Sea Heart' ", "'Silver Heart' ", "'Marvalette Blue'",
#        "'Auenwald'", "'Blue'", "Planet'", "'Avida Blue'",
#        "'Elizabeth Oliver'", "'Freya'  ", "'Genti Blue' ", "Bells'",
#        "(x) 'Viking'  ", "Way'", "'Coerulea'", "'Stella Blue'",
#        "'Amethyst in Snow'©", "'Rosenrot'", "'Silberteppich'", "Curtis'",
#        "Edinburgh'", ' ', "'SolannaGolden Crown'", "'Cherry Pie'",
#        "(x) 'Little Bang Red Elf'", "(x) 'Little Bang Starlight'",
#        "(x) 'Snowberry' ", "Heron'", "'Blue Panda'", "'Purple Leaf'",
#        "'Eclipse' ", "McKenzie'", "Davidson'", "King'", "Fairy Crimson'",
#        "Fairy Gold'", "x 'Sundella Apricot'", "x 'Sundella Neon'",
#        "x 'Sundella Orange'", "x 'Sundella Red'",
#        "Fountain Dark Blue with Dark Bee'", "Fountain Pure White'",
#        "Fountain Sky Blue with White Bee'", 'MILLENNIUM ‘Purple Passion’',
#        'MILLENNIUM ‘Royal Aspirations’', "'Pacific Astolat'",
#        "Black Knight'", "Blue Bird'", "Galahad'", "King Arthur'",
#        "Summer Skies'", "'Brilliant'", "'Grandiflorus'",
#        "'Angel of Hope'", "'Angel of Purity'", "'Angel of Virtue' ",
#        "Hearts'", "'Adrian Bloom'", "'Bacchanal'", "'Luxuriant'",
#        "of Hearts'", "Fountain'", "'Valentine'", "'Albiflorus'",
#        "'Berry Canary'", "(x) 'Illumination Apricot'",
#        "(x) 'Illumination Rasberry'()", "'Queen Victoria'",
#        "'Leonardo Compact'", 'NARECZNICA', "'Pinderi'",
#        'syn.crassirhizoma', "'Barnesii'", "'Linearis Polydactyla'",
#        "'Aloha'", "'Big Kahuna'  ", "'Blueberry Cheesecake' ",
#        "'Butterfly Kisses'", "'Carrot Cake'", "'Cherry Fluff'",
#        "'Cheyenne Spririt'", "'Cleopatra'", "'Delicious Candy'",
#        "'Delicious Nougat' ", "'Doubledecker'", "'Eccentric'",
#        "'Flame Tower'", "'Fountain Pink Eye'", "'Fountain Red' ",
#        "'Glowing Dream'", "'Green Jewel'", "'Honey Skipper'",
#        "'Hot Papaya'", "'Innocent Meadow Mama' ", "'Julia'",
#        "'Kismet Yellow'", "'Leilani'", "'Lemon Drop'", "'Magenta Pearl'",
#        "'Magnus'", "'Marmalade'", "'Meditation Cerise'",
#        "'Meditation White' ", "'Meringue'", "'Milkshake'", "'Parrot'",
#        "'Pink Tip'", "'Prima Ginger'", "'Rainbow Apricot'",
#        "'Rainbow Yellow' ", "'Raspberry Truffle'", "'Red Pearl'",
#        "'Red Skipper'", "'Secret Glow'", "'Southern Belle'",
#        "'Strawberry & Cream' ", "'Supreme Cantaloupe'", "'Tomato Soup'",
#        "'White Pearl'", "'White Rose-Wine'", "'Yellow Pearl'",
#        "'Toplow Blue'", "'Veitch's Blue'", "(x) 'Romance'", "Aller'",
#        "'Bishop's Form'", "Eijking'", "'Blauer Zwerg'", "(x) 'Big Blue'",
#        "'Baby Joe'", "subsp. wulfenii 'Shorty'", "'Ascot Rainbow' ",
#        "'Glacier Blue'", "'Tasmanian Tiger' ", "'Spider's Web'",
#        "'Tom Thumb'", "'Mr Popple'", "'Lady Thumb'", "'Mesa Yellow'",
#        "'Mesa Red'", "'Mesa Peach'", "'Cherry Brandy' ",
#        "'Graceful White' ", "'Passionate Blush'", "'Rosy Jane'",
#        "'Siskiyou Pink'", "'Snowbird'", "'Snowstorm'", "'Tutti Frutti'",
#        "'Whirling Butterflies'", "'White Dove'", "Pink' ",
#        "'Totally Tangerine' ", "Alamaba Sunrise' ", "'Nonna' ",
#        "'Pink Petticoats'", "'Samba Sunset' ", "'Flames of Passion' ",
#        "'Mai Tai' ", "'Biokovo'", "'Cambridge'", "'St. Ola'",
#        "'Ballerina'", "'Purple Pillow'", "'Sateene'", "'Baby Blue'",
#        "'Gravetye'", "'Plenum'", "'Pink Penny'  ", "'Bevan's Variety'",
#        "'Czakor'", "'Ingwersen'", "'Spessart'", "'Samobor'",
#        "BLACK BEAUTY 'Nodbeauty'", "'Cloud Nine' ", "'Mrs Kendall Clark'",
#        "'Storm Cloud' ", "'Gerwat'", "'Max Frei'", "'Tiny Monster'",
#        "HAVANA BLUES 'Noorthava'", '- czerwona', "Flora' - fiolet",
#        "Lux' - żółte", "Tart' - ciemny róż", "'Festival White Flare' ",
#        "hybridum 'Moerheim Beauty'", "hybridum 'Carmen'",
#        "hybridum 'Bandera'", "hybridum 'Poncho' ", "Whammy' ",
#        "Pure Gold' ", "'Sunshine Daydream'", "'Korma' ", "'Goldgrünherz'",
#        "'Loraine Sunshine'", "'Praecox'",
#        '\'Double Ellen\': 70\'Spotted\'; 70\'Picotee\'; 70\'Pink\'; 75\'Purple\'; 75\'Red\'; 70\'White\'; 70\'White Spotted\'"',
#        "Magic'", "Snow'", "Mitchell'", "Lugosi'", "Eyed Suzan'",
#        "Stockings'", "Kings'", "Circle'", "Emperor'", "Woodbury'",
#        "of Angels'", "Blackout'", "Pirate'", "Dream'", "Fanfare'",
#        "Joiner'", "Hals'", "Wheelin'", "Lord'", "Swan'", "Senior'",
#        "Wyszyński'", "of Cotton'", "Anwar'", "Kolbe'", "Tood'", "Fire'",
#        "My Eyes'", "Candy'", "Parassol'", "Rum'", "Bauer'", "Fritz'",
#        "de Oro'", "Wine'", "Russel'", "Look'", "Fluff'", "of Love'",
#        "Temptation'", "Horses'", "Timble'", "Angel'", "Forest'",
#        "Crisp'  ", "Leaves'  ", "Color'", "Marmolade'  ", "Smoothie'  ",
#        "Beauty'  ", "Pearl'  ", "Taffeta'  ", "Fire'  ", " Can'",
#        "Cola'  ", "Silver'  ", "Dawn'  ", "Drop'", "Chief'  ", "Peach'  ",
#        "Plum'  ", "Ale'  ", '25019 ', "Expectation'  ", "Spice'",
#        "Dancer'  ", "Cutie Blondie in Lime'  ", "Cutie Blondie'  ",
#        "Cutie Coco'  ", "Cutie Sweet Tart'  ", "Marble'",
#        "Marble Silver'", "'Palace Purple'", "Touch'  EU-derir",
#        "Rose' Select   EU-dv", "Exposure Amber'  ", "Flambe'  ",
#        "Spice'  ", "Panther' ", "Pudding' ", "Lightning'  ", "Black' ",
#        "Dark Amber'", "Fire' ", "Lime'", "Peppermint'  ", "Purple'  ",
#        "Amber' ", "Black'", "Gumdrop' ", "Scrolls' 2000/", "Night'",
#        "Rose' ", "Caffé Romano'", "Rum'  ", "Cascade'  ", "Ice'  ",
#        "Zebra'  ", "Revolution'  ", "Eclipse'  ", "Tea'  ",
#        "XXL 'Mauvelous'", "Drinking Gourd'", "of Gold'", "Hallo'",
#        "Frost' ", "Daddy'", "Mouse Ears'", "Cup'", "Berry'", "Queen'",
#        "and Ice'", "Standard'", "Meadows'", "Tiara'", "Waffels'",
#        "Expectations'", "Regal'", "Cupcake'", "Man'",
#        "Before Christmast'", "Marmalade'", "Glory'", 'var.grandiflora',
#        "Hands'", "Heart'", "Sunrise'", "Sundae'", "October'", "Splendor'",
#        "Mouse' ", 'Cost to Cost', 'Wu La La ', "'Diamond Lake'", "'Hans'",
#        "& Substance'", "Glass'", "'Mediovariegata'", ' CAF', "Brim'",
#        "'Masterpiece'", "'Pink Ice' ", "'Purity'", "'Whistler'",
#        "'Snowtop'", "'Black Form'", "'Black Dragon'", "'Cherished'",
#        "'Edith Wolford'", "'Rubin Blue'", "'Senlac'", "'Shazam'",
#        "'Siva Siva'", "'Banbury Ruffles'", "'Blue Denim'",
#        "'Cherry Garden'", "'Velvet Carpet'", "'Bellissima'",
#        "'Blue King'", "'Butter and Sugar'", "'Caesar's Brother'",
#        "'Contranst in Styles'", "'Currier'", "'Dawn Waltz'",
#        "'Double Standard'", "'Flight of Butterflies'", "'Gull's Wing'",
#        "'Harpswell Happiness'", "'Harpswell Haze'", "'Harpswell Velvet'",
#        "'Having Fun'", "'Kabluey'", "'Lavender Bounty'", "'Miss Apple'",
#        "'Perry's Blue'", "'Persimmon'", "'Rikugi Sakura'", "'Rose Quest'",
#        "'Rosebud Melody'", "'Rufflet Velvet'", "'Snow Queen'",
#        "'Sparkling Rose'", "'Temper Tantrum'", "'Valda'", "'Wine Wings'",
#        "'Nana Blue'", "'Antonia'", "'Mango Popsicle'  ", "Jr.'",
#        "'Papaya Popsicle'  ", "'Redhot Popsilce' ", "'Herman's Pride'",
#        "'Purple Dragon'", "'Florentinum'", "'May Snow'",
#        "'Platt's Black'", "'Sweet Daisy Cher' ", "(x) 'Goldfinch'  ",
#        "(x) 'Luna'   ", "(x) 'Real Glory' ", "(x) 'Real Neat' ",
#        "(x) 'Snow Cap'", "'Kobold'+", "'Britt-Marie Crawford'",
#        "'Desdemona'", "'Garden Confetti'", "'Twilight'",
#        "(x) 'Gregynog Gold'", "'The Rocket'", "Tiger' (żółta)",
#        "Tiger' (czerwona)", '(pomarańczowa)', "Tiger' (biała)",
#        '(różowa)', '(j.róż', '(ciemno czerwona)', "Charm' (bordowa)",
#        '(złoto-żółta)', "'Manitoba Morning' (różowo-pomarańczowa)",
#        "'Guinea Gold' (żółta)", "'Maroon King'' (różowo-śliwkowa)",
#        "'Pink Morning' (jasno-różowaa)", "Beauty' (ciemny róż)",
#        "Pixie' (żółta)", "Blanca' (biała)", "d'Or' (kremowo-żółta)",
#        '(czerwona)', "Pixie' (czerwono-pomar)", '(kremowa)', '(biała)',
#        '(różowo-żółta)', '(żółta)', '(maślano-miodowy)',
#        "Joy' (pomarańczowa)", "Pixie' (pomarańcz)", '(kremowo-żółta)',
#        '(czerwono-różowa)', "Palace' (różowa)",
#        "Pixie' (różowa-tygrysia)", "Lady' (różowa  żółty środek)",
#        "Dutch' (czerwono-żółta)", '(różówa)', '(ciemno-różowa)',
#        '(biała pełna)', "'Grace Ward'", "'Black Truffle' ",
#        'WEST COUNTRY COLLECTION', "'Desert Sun'", "'Manhattan Lights' ",
#        "'Persian Slipper' ", "'Rachel de Thame' ", "'Salmon Star' ",
#        "'Tequila Flame' ", "'Towering Inferno' ", "'Vesuvius'",
#        "'Beaujolais'", "'Firecracker'", "'Autumn Snow'", "'Senior'",
#        "'Happy Lights'", "'Morden Pink'", "'Robert'", "'Pink Blush'",
#        "'Zigeunerblut'", "'Purple'", "'Royal Velvet Distinction'",
#        "'Blue Moon'", "'Suger Buzz Bubblegum Blast' ",
#        "''Elsie's Lavender'", "(x) 'Blue Wonder'", "(x) 'Junior Walker' ",
#        "(x) 'Purrsian Blue'  ", "(x) 'Six Hills Giant'",
#        "(x)'Walker's Low'", "NEPTUNE 'Bokratune' ", "'Starry Eyes'",
#        "'Amethyst Falls' ", "de Nemours'", "Sunset'", "Bockstoce'",
#        "Rosenfield'", "Alexander Duff'", "Brand'", "Emile Debatene'",
#        "Shaylor''", "'Rubra Plena'", "Charm'", "Fe'", "Bernhardt'",
#        "Temple'", "Niemcewicz'", "Sarah Bernhardt'",
#        "'Spring Fever'TM MIX", "'Beauty of Livermere'",
#        "'Onyx and Pearl' ", "'Dark Towers'  ", "'Blackfield'",
#        "'JS Seven Oaks Village' TM ", "'JS Caliente'  ",
#        "'Darjeeling Red'", "'Amazone'", "'Bronze Flamingo'",
#        "'Early Cerise'", "'Early Red'", "'Early White'", "'Flame Coral' ",
#        "'Flame Light Blue' ", "'Flame Pink Eye'", "'Flame Pink'",
#        "'Flame Pro Cerise' ", "'Flame Pro Pink Pop' ",
#        "'Flame Pro Soft Pink'", "'Flame Pro Violet Charm' ",
#        "'Flame Purple Eye' ", "'Flame Ruby'", "'Flame White Eye'",
#        "'Nadia'", "'Peppermint Twist'", "'Swizzle'  EU ",
#        "'Spring Dark Pink'", "'African Queen'", "(x) 'Cherry Ripe'",
#        "'Cristata'", "'Rosea'", "'Vivid'", "'Astra Blue'", "'Astra Pink'",
#        "Dotty'  ", "'Touch of Class' 2008/", "'Heaven Scent'",
#        "'Congestrum'", "'Dahlem'", "'Plumosum Densum'", "'Proliferum'",
#        "'Red'", "'Nuuk'", 'ssp. Mooreana', "'Blue Selection'",
#        "'Corolla Blue'", "'Corolla Deep Rose'", "'Corolla White'",
#        "'Rubin'", "'Miller's Crimson'", "'Cabrillow Yellow'",
#        "'Cabrillo Yellow'", "'Golden Nugget White'",
#        "'Little Queen White'", "'Gold Nugget Red'",
#        "'Little Queen Yellow'", "'Gold Nugget Purple'",
#        "'Alison Holland' ", "Innisfree 'K72'", "on the Barbie' ",
#        "Bouquet'", "'Pinwheel Blue Violet Shades'", "'Pinwheel Dark Red'",
#        "'Pinwhell White'", "(x) 'Magic Dragon'", 'var.tanguticum',
#        "'Rhubarb'", "Peacock'  ", "'Happy SmileyZ' ",
#        "'Laughing SmileyZ' ", "'Kissing SmileyZ' ", " ('Berlijn')",
#        "'Goldsturm'", "'Goldquelle'", "'Herbstonne'", "'Green Wizard'",
#        "Olivia'' ", "Alicia (006)' ", "Juliana' ", "'Amethyst Lips' /",
#        "'Blue Note' ", "'Cherry Lips' ", "'Royal Bumble'",
#        "'Black and Blue'", "(x) 'Carina'", "'Adrian'", "'April Night'",
#        "'Blauköningin'", "'Blue Bouquetta'", "'Blue Field'  ",
#        "'Caradonna'", "'Salute Deep Blue'", "MARCUS  'Haeumanarc'",
#        "'Merleau Blue'", "'Merleau White'", "'Mervel Blue'",
#        "'Midnight Rose' ", "'Night Field'   ", "'Ostfriesland'",
#        "'Pink Field'  ", "'Rianne' ", "'Salute Ice Blue'",
#        "'Salute Light Pink' ", "'Salute Pink'", "'Salute White'",
#        "'Sensation' Deep Blue'", "'Purple Rain'", "'Lilac Squirrel'",
#        "'Pink Tanna'", "'Tanna'", 'var.alba', 'var.purpurea',
#        "(x) 'Alpino Early Carnival'", "(x) 'Alpino Early Lime' ",
#        "(x) 'Alpino Early Magical Picotee'",
#        "(x) 'Alpino Early Magical Rose'",
#        "(x) 'Alpino Early Magical Salmon'", "(x) 'Scenic Red' ",
#        "(x) 'Scenic White' ", "'Perfecta Alba'", "'Mariposa Blue'",
#        "'Vivid Violet'  ", "'Pink Diamonds'", "var.alpina 'Ritz Blue'",
#        "'Matrona'", "'Angelina'", "'Chocolate Ball'  ", "'Gold'",
#        "'Mediovariegatum'", "'Cape Blanco'", "'Purpureum'",
#        "'Cloud Walker'  ", "'Hot Stuff' ", "Cherry Tart'", "Dazzlebery'",
#        "Dream Dazzler'", "Jade Tuffet'", "Lime Zinger'", "'Mr. Goodbud' ",
#        "'Thunderhead'  ",
#        '\'Cassiopea\'; Dr.Fritz Kohlein\'; \'Draco\'; \'Leo\'; \'Sirius\')"',
#        '(\'Chrome Green\'; \'Coral Gray\'; \'Country Red\'; \'Pink Pomelo\'; \'Purple Quartz\'; \'Ruby Star\')"',
#        "'Elsie Heugh'", 'LEPNICA', "(x) 'Rolly's Favorite' ",
#        "'Aunt May'", "Anioła'", "'Silver Carpet'", "'Hummelo'",
#        "'Wisley Blue'", "'Little Frosty'", "'Black Stockings'  ",
#        "'Nimbus White'  ", "'Hewitt's Double'", "'Coccineus'",
#        "'Pink Chintz'", "Grape'", "'Golden Queen'", "Eyes' ", "Dijon'",
#        "Domino'", "'Homestead Purple'", "'Santos'", "'First Choice'  ",
#        "'First Glory'", "'First Lady'  ", "'First Match' ",
#        "'Bubblegum Candles'", "ROYAL CANDLES 5056 'Glory'", "'Adoration'",
#        "'Lavendelturm'", "'Red Arrows'", "'Boughton Blue'",
#        "'Molly Sanderson'", "'Dark Freckles'", "'Color Guard'",
#        "'Blue Ice'", "'JWW10'  Prettycoat", "Globe'", "'Curly Red'",
#        "'Zeblid'", "BURNING LOVE 'Opstal50'", "'Carnaval'", "'Cupido'",
#        "'Flaming Silver'", "'Forest Flame'", "'Little Heath'",
#        "'Mountain Fire'", "'Passion'", "'Sarabande'",
#        "'Valley Valentine'", '(AI)', "mollis) 'Doloroso'",
#        '15 \'Amoena\'; 15 \'Rdja\'; 15 \'Insurpassable\'=\'Thierry\'; 15 \'Luzi\'"',
#        '(Gibraltar  Gold Topas; Royal Command)"', "'Amoenum'",
#        'mollis) \'Sarina\'; \'Nabucco\'; \'Klondyke\'; \'Gibraltar\'; \'Fireball\'"',
#        'mollis) ',
#        'KH): \'Barselik\'; Homebush\'; \'Lutum\'; \'My Reini\'; \'Tunis\'"',
#        "'Gibraltar'",
#        'mollis) 20 \'Berryrose\'; 20 \'Gibraltar\'; 20 \'Glowing Embers\'; 20 \'Golden Eagle\'; 20 \'Persil\'; "',
#        '2022 \'Tatjana\'; \'Morgentot\'; \'Polaris\'; \'Anuschka\'"',
#        'C5+', '15 \'Blue Diamond\'; 15 \'Ramapo\'"', 'C7 5+', 'C10 40-',
#        "'Kaichiro Wada'", '(Arabella; Schneekrone)"',
#        '\'Anah Kruschke\'; 10 \'Anna Rose Whitney\'; 6 \'Chionoides\'; 10 \'Etoile de Sleidinge\'; 5 \'Nancy Evans\'; 10 \'Rasputin\'; 10 \'Virginia Richards\'; 10 \'Mrs T.H.Lowinsky\'"',
#        '\'Double Dots\'; 20 \'Dramatic Dark\'; 15 \'Metallica\'; 10 \'Midnight Mystique\';    10 \'Praecox\'"',
#        "10 'Blue Diamond'", '\'Markeeta\'s Prize\')"', "Menard'",
#        '2\'Anah Kruschke\'; 2\'Anna Rose Whitney\'; 3\'Cosmopolitan\'; 6\'Germania\'; 5\'Markeeta\'s Prize\'"',
#        "'Argenteostriatus'", "'Ely'", "'Versicolor'", "'Little Lilia'",
#        "(x) 'Avalanche'", "(x) 'England'", "(x) 'Overdam'",
#        "(x) 'Karl Forster'", "'Aureomarginata'", "'Jenneke'",
#        "'Lady Sunshine'", "'Racing Green'", "'Green Twist'",
#        "'Red Rooster'", "'The Beatles'", "'Amazon Mist'",
#        "'Frosted Curls'", "MILK CHOCOLATE 'Milchoc'", "'Hime Kansuge'",
#        "Falls' ", "'Bronze Form'", "'Ice Dance'", "'Vanilla Ice' ",
#        "'Little Midge'", "'Evergold'", "'Goldwell'", "'Maxigold'",
#        "'Moonlight'", "'Ribbon Falls' ", "'Pamira'", "'Purple Tower'",
#        "'Green Goblin' ", "'Junior'", "'Pumila'", "'Tiny Pampa'",
#        "'Bronzeschleier'", "'Goldschleier'", "'Tatra Gold'", '- SKRZYP',
#        '„Robustum”', "'Lancaster' (dorasta 2-4m  mrozoodporność: -24˚C)",
#        "1' (dorasta 2-3m 5m  mrozoodporność: -28˚C)",
#        "'Bimbo' (dorasta 1-1  mrozoodporność: -24˚C)",
#        "'Simba'' (dorasta 3-4m  mrozoodporność: -28˚C)",
#        "'Dino' (dorasta 2-3m  mrozoodporność: -24˚C)",
#        "'Simba' (dorasta 2-2 5m  mrozoodporność: -21˚C)",
#        "'Jumbo' (dorasta 3-4m  mrozoodporność: -25˚C)",
#        "'Black Pearl' (dorasta 2-3m  mrozoodporność: -28˚C)",
#        "'Great Wall' (dorasta 4m  mrozoodporność: -28˚C)",
#        "'Obelisk' (dorasta 3-4m  mrozoodporność:     -25˚C)",
#        "'Volcano' (dorasta 2-3m   mrozoodporność: -26˚C)",
#        "'Pingwu' (dorasta 2-3m  mrozoodporność: -21˚C)",
#        '(dorasta 2-3m  mrozoodporność: -30˚C)', "INTENS BLUE 'Casblue'",
#        "'Blauglut'", "'Eisvogel", "'Elija Blue'", 'AmiGold',
#        "INTENS BLUE  'Casblue'", "'Pic Carlit'", "'Frosty Morning'",
#        "'Aureola'", "'Beni Kaze'", "'Greenhills'", "'Mulled Wine' ",
#        "'Stripe it Rich'", "'Saphirsprudel'", "'Jackdawn's Cream'",
#        "'Coolio'", "'Blue Dune'", "'Moneymaker'", "'Monroe White'",
#        "'Igel'", 'x', "x 'Aligator'", "'Adagio'", "'Boucle' ",
#        "'Cabaret'", "'Emmanuel Lepage'", "'Ferner Osten'",
#        "'Gracillimus'", "'Graziella'", "'Grosse Fontäne'",
#        "'Guntenberg Gold'", "'Kleine Silberspinne'", "'Kleine Fontane'",
#        "'Little Zebra'", "'Malepartus'", "'Memory'", "'Morning Light'",
#        "'Polonus' ", "'Pünktchen'", "'Red Cloud'", "'Rosi'",
#        "'Silberspinne'", "'Strictus'", "'Zebrinus'", "'Karl Foerster'",
#        "'Skyracer'", "'Heidebraut'", "'Heidezwerg'", "'Moorhexe'",
#        "'Niger'", "'Buffalo Green' ", "'Heavy Metal'", "'Nosferatu' ",
#        "'Prairie Sky'", "'Purple Breeze'",
#        "'Rotstrahlbusch' (dawniej'Hanse Herms')", "'Shanandoah'",
#        "'Warrior'", "'Rubrum'", "'Black Beauty'", "'Gelbstiel'",
#        "'Hameln'", "'Lady U'", "'Little Bunny'", "'Moudry'",
#        "'National Arboretum'", "'Red Head'", "'Viridescens'", "'Pegasus'",
#        "'Vertigo'", "'Feesey'", "'Picta'", "'Evening Glow'",
#        'var.communis', '(dorasta 4-5m  mrozoodporność: -20˚C)',
#        "'Spectabilis' (dorasta 4-5m  mrozoodporność: -28˚C)",
#        '(dorasta 3-5m  mrozoodporność: -25˚C)',
#        ' (dorasta 3-5m  mrozoodporność: -21˚C)',
#        "'Aureocaulis' (dorasta 4-5m  mrozoodporność: -28˚C)",
#        "'Albescens'", "'Praire Blues'", "'Standing Ovation'",
#        "'Smoke Signal' ",
#        'var. viridis (dorasta 5-7m  mrozoodporność: -21˚C)',
#        "'Indian Steel'", "'Ponytails'", "'Silberkugel'", "'Wellenseind'",
#        "'Crikov'", "'Logan Pass'", "'Prickley Pete'", "'Rumburk'",
#        "'Rimpelaar'", 'w odm.', "'Bolesław Chrobry'", "'Chris's Dwarf'",
#        "'Kaizuka'", "'Kishiogima'", "'Monarch'", "'Stiff Weeper'",
#        "'Matthaei Broom'", "'Schirrmann's Nordlicht'", "'Keightly Broom'",
#        "'Lilliput'", "Varella'", "'Birte'", "'Summer Breeze'",
#        "'Tempelhof'", "'Toyoki Green'", "'Pevé Minaret'",
#        "'Cascade Falls'", "(x) 'Brownii'", "(x) 'Sebian'",
#        "(x) 'Thayerae'", ' w odmianach', "'Eco Sentry'", "'Elsrijk'",
#        "'Magic Spring'", "'Red Shine'", "AUTUMN BLAZE 'Jeffersred'",
#        "SUNSET 'Warrenred'", "'Columnare'", "'Drummondii'",
#        "'Faassen's Black'", "'Globosum'", "'Globos+um'",
#        "PRINCETON GOLD 'Prigo'", "'Purple Globe'", "'Brilliantissimum'",
#        "'Leopoldii'", "'October Glory'", "'Red Sunset'", "'Hot Wings'",
#        'subsp. ginnala', "(x) 'Briotii'", "'Baumannii'",
#        "'Umbraculifera'", "'Robin Hill'", "'Laciniata'", "'Obelisk'",
#        "Spider Alley'", "'Youngii'", "'Doorenbos'", "'Long Trunk'",
#        "'Frans Fountaine'", "'Krukenberg Dwarf'", "'Marioka Weeping'",
#        "(x) 'Paul's Scarlet'", "'Albomarginata'", "'Ansorgei'",
#        "'Black Swan'", "'Dawyck'", "'Dawyck Gold'", "'Dawyck Purple'",
#        "MIDNIGHT FATHER 'Verschuurfag 1'", "'Purple Fountain'",
#        "'Purpurea Pendula'", "'Rohan Green Weeping'", "'Rohan Obelisk'",
#        "'Rohan Weeping'", "'Slovensko'", "'Tricolor'", "'Sunburst'",
#        "'Resi'", "(x) 'Vossii'", "'Gum Ball'", "'Oconee'",
#        "'Slender Silhouette'", "'Stella'", "'Worplesdon'", "'Snow Bird'",
#        'PERPETU', "Chopin'", "Hornet'", "Sprenger'", 'alba',
#        "(x) 'Umbraculifera'", "'Caucasica'", "'Genolia'", "'Rancho'",
#        "'Shubert'", "'Chanticleer'", "(x) CRIMSON SPIRE 'Crimschmidt'",
#        "'Green Pillar'", "'Concordia'", "'Fastigiate Koster'",
#        "'Wolfsdonk's Pride'", "TIGER EYES  'Baitiger'cov", "'Dissecta'",
#        'ROBINIA', "'Lombarts'", "TWISTY BABY 'Lace Lady'", "'Unifoliola'",
#        "(x) 'Chrysocoma'", "'Karaca Weeping'", "'Lutescens'",
#        "'Magnifica'", "'Edulis'", "'Fingerprint'", "'Gibbsii'",
#        "'Brouwers'                    ", "'Brouwers'", "'Greenspire'",
#        "(x) 'Euchlora'", "'Arnold Select'", "'Varsaviensis'", "'Hugin'",
#        "'Viking'", "'Jolico'", "'Brown Turkey'", '- Poziomka)',
#        "(x) 'Florence'", "'Rugia'", "'Frugana'", 'szczepiony',
#        "'Docz' Velkana'", "var.longifolia 'Wojtek'", "'No. 1'",
#        'Kolumnowe', '(Morela)', '(Wiśnia)', '(Śliwa)',
#        ' (Brzoskwinia  Nektaryna)', 'kolumnowa', "'Konferencja'",
#        '(Grusza) f.kolumnowa', "'Blanka'", "'Titania'", "'Rolan'",
#        "'Jonkheer van Tets'", 'HINNONMÄKI RÖD', "'Himalaya'",
#        "'Oregon Thornless'", "'Polana'", "'Glen Ample'", "'Polka'",
#        "'Tulameen'", "'Malling Promise'", "'Polesie'", "'Haschberg'",
#        "'Chandler'", "'Darrow'", "'Goldtraube 23'", "'Northland'",
#        "'Spartan'", "'Patriot'", "'Pilgrim'", "Muscat'", 'w dmianach',
#        '(Malus  Prunus  Pyrus)', 'w odmianach', 'DUO', "'Dentata'",
#        "'Thorndale'", 'subsp.petiolaris', 'CHMIEL', 'var. murorum',
#        "'Green Spring'", "'Veitchii'", "'Shiro-noda'", "'Caroline'",
#        "'Prolific'"], dtype=object)

# %%
df.to_csv("ver2_0.csv")

# %%
df['A'].str.findall("\'[A-Z][a-z]+\'$").tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[523], line 1
# ----> 1 df['A'].str.findall("\'[A-Z][a-z]+\'$").tolist()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'A'
